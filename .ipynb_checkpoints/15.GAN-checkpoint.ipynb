# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
import os
if not os.path.exists("./gan_images"):
    os.makedirs("./gan_images")

# %%
# 생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))

# %%
generator.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 6272)              633472
# _________________________________________________________________
# batch_normalization (BatchNo (None, 6272)              25088
# _________________________________________________________________
# reshape (Reshape)            (None, 7, 7, 128)         0
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 14, 14, 64)        204864
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# activation (Activation)      (None, 14, 14, 64)        0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 1)         1601
# =================================================================
# Total params: 865,281
# Trainable params: 852,609
# Non-trainable params: 12,672
# _________________________________________________________________

# %%
# 판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False

# %%
discriminator.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 14, 14, 64)        1664
# _________________________________________________________________
# activation_1 (Activation)    (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 128)         204928
# _________________________________________________________________
# activation_2 (Activation)    (None, 7, 7, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 6273
# =================================================================
# Total params: 212,865
# Trainable params: 0
# Non-trainable params: 212,865
# _________________________________________________________________

# %%
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential (Sequential)      (None, 28, 28, 1)         865281
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 212865
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________

# %%
def gan_train(epoch, batch_size, saving_interval):
    (X_train, _), (_, _) = mnist.load_data()
    X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
    X_train = (X_train - 127.5) / 127.5
    true = np.ones((batch_size, 1))
    fake = np.zeros((batch_size, 1))
    
    for i in range(epoch):
        idx = np.random.randint(0, X_train.shape[0], batch_size)
        imgs = X_train[idx]
        d_loss_real = discriminator.train_on_batch(imgs, true)
        
        noise = np.random.normal(0, 1, (batch_size, 100))
        gen_imgs = generator.predict(noise)
        d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)
        
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
        g_loss = gan.train_on_batch(noise, true)
        
        print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)
        
        if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)

              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5

              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("gan_images/gan_mnist_%d.png" % i)

# %%
gan_train(4001, 32, 200)
# Out:
# epoch:0  d_loss:0.7084  g_loss:0.8193
# epoch:1  d_loss:0.4201  g_loss:0.7402
# epoch:2  d_loss:0.4431  g_loss:0.3619
# epoch:3  d_loss:0.5251  g_loss:0.1711
# epoch:4  d_loss:0.5934  g_loss:0.1938
# epoch:5  d_loss:0.5273  g_loss:0.3157
# epoch:6  d_loss:0.4581  g_loss:0.5599
# epoch:7  d_loss:0.5430  g_loss:0.5474
# epoch:8  d_loss:0.5792  g_loss:0.3863
# epoch:9  d_loss:0.5597  g_loss:0.3044
# epoch:10  d_loss:0.5293  g_loss:0.3326
# epoch:11  d_loss:0.4629  g_loss:0.5337
# epoch:12  d_loss:0.3689  g_loss:0.8787
# epoch:13  d_loss:0.2855  g_loss:1.4531
# epoch:14  d_loss:0.2669  g_loss:2.1703
# epoch:15  d_loss:0.2524  g_loss:2.2721
# epoch:16  d_loss:0.2471  g_loss:2.3070
# epoch:17  d_loss:0.2217  g_loss:2.4473
# epoch:18  d_loss:0.3107  g_loss:2.5821
# epoch:19  d_loss:0.4289  g_loss:2.8402
# epoch:20  d_loss:0.3535  g_loss:3.4279
# epoch:21  d_loss:0.4104  g_loss:2.6047
# epoch:22  d_loss:0.3979  g_loss:2.5461
# epoch:23  d_loss:0.3362  g_loss:2.2820
# epoch:24  d_loss:0.2096  g_loss:2.5683
# epoch:25  d_loss:0.3489  g_loss:1.9261
# epoch:26  d_loss:0.2287  g_loss:1.7329
# epoch:27  d_loss:0.2468  g_loss:2.1022
# epoch:28  d_loss:0.2814  g_loss:2.1158
# epoch:29  d_loss:0.2833  g_loss:2.1457
# epoch:30  d_loss:0.3288  g_loss:1.8150
# epoch:31  d_loss:0.3019  g_loss:2.1727
# epoch:32  d_loss:0.3218  g_loss:2.6465
# epoch:33  d_loss:0.4232  g_loss:2.0770
# epoch:34  d_loss:0.3491  g_loss:1.4856
# epoch:35  d_loss:0.5213  g_loss:1.7319
# epoch:36  d_loss:0.4124  g_loss:2.7436
# epoch:37  d_loss:0.3968  g_loss:2.5018
# epoch:38  d_loss:0.3211  g_loss:2.0526
# epoch:39  d_loss:0.2646  g_loss:2.6073
# epoch:40  d_loss:0.0987  g_loss:3.5896
# epoch:41  d_loss:0.2619  g_loss:3.3470
# epoch:42  d_loss:0.2276  g_loss:2.6749
# epoch:43  d_loss:0.6703  g_loss:3.3498
# epoch:44  d_loss:0.4741  g_loss:3.7365
# epoch:45  d_loss:0.4437  g_loss:4.5834
# epoch:46  d_loss:0.9972  g_loss:2.4737
# epoch:47  d_loss:0.6788  g_loss:1.4648
# epoch:48  d_loss:0.6161  g_loss:2.1725
# epoch:49  d_loss:0.3381  g_loss:2.9559
# epoch:50  d_loss:0.4862  g_loss:2.7565
# epoch:51  d_loss:0.4319  g_loss:1.8915
# epoch:52  d_loss:0.4908  g_loss:1.2955
# epoch:53  d_loss:0.3218  g_loss:1.7247
# epoch:54  d_loss:0.2984  g_loss:2.3371
# epoch:55  d_loss:0.2960  g_loss:2.5156
# epoch:56  d_loss:0.8998  g_loss:1.5083
# epoch:57  d_loss:0.5602  g_loss:0.8786
# epoch:58  d_loss:0.4131  g_loss:0.9080
# epoch:59  d_loss:0.5225  g_loss:1.1279
# epoch:60  d_loss:0.3549  g_loss:1.7812
# epoch:61  d_loss:0.5830  g_loss:1.8879
# epoch:62  d_loss:0.6509  g_loss:1.2528
# epoch:63  d_loss:0.5237  g_loss:0.8921
# epoch:64  d_loss:0.6048  g_loss:1.0035
# epoch:65  d_loss:0.3515  g_loss:1.5861
# epoch:66  d_loss:0.2759  g_loss:2.2190
# epoch:67  d_loss:0.3148  g_loss:2.3499
# epoch:68  d_loss:0.3992  g_loss:1.9007
# epoch:69  d_loss:0.3614  g_loss:2.0776
# epoch:70  d_loss:0.5365  g_loss:1.5118
# epoch:71  d_loss:0.3417  g_loss:2.2000
# epoch:72  d_loss:0.4115  g_loss:2.5346
# epoch:73  d_loss:0.9352  g_loss:1.9477
# epoch:74  d_loss:0.7426  g_loss:1.2494
# epoch:75  d_loss:0.5764  g_loss:1.4237
# epoch:76  d_loss:0.7344  g_loss:1.9002
# epoch:77  d_loss:0.6976  g_loss:2.0753
# epoch:78  d_loss:0.6755  g_loss:1.6785
# epoch:79  d_loss:0.5248  g_loss:1.5099
# epoch:80  d_loss:0.5143  g_loss:1.4792
# epoch:81  d_loss:0.4253  g_loss:1.6509
# epoch:82  d_loss:0.4540  g_loss:1.6977
# epoch:83  d_loss:0.4021  g_loss:1.8884
# epoch:84  d_loss:0.2776  g_loss:2.3138
# epoch:85  d_loss:0.5817  g_loss:1.6486
# epoch:86  d_loss:0.5900  g_loss:1.0431
# epoch:87  d_loss:0.5120  g_loss:0.9387
# epoch:88  d_loss:0.4570  g_loss:1.0188
# epoch:89  d_loss:0.5490  g_loss:1.3938
# epoch:90  d_loss:0.3888  g_loss:1.7257
# epoch:91  d_loss:0.5056  g_loss:1.9423
# epoch:92  d_loss:0.7122  g_loss:1.1671
# epoch:93  d_loss:0.4135  g_loss:1.1312
# epoch:94  d_loss:0.4458  g_loss:1.0635
# epoch:95  d_loss:0.4493  g_loss:1.2171
# epoch:96  d_loss:0.4130  g_loss:1.5223
# epoch:97  d_loss:0.5210  g_loss:1.3814
# epoch:98  d_loss:0.4879  g_loss:1.4921
# epoch:99  d_loss:0.5322  g_loss:1.4684
# epoch:100  d_loss:0.4287  g_loss:1.8475
# epoch:101  d_loss:0.4003  g_loss:1.9270
# epoch:102  d_loss:0.3642  g_loss:2.1215
# epoch:103  d_loss:0.4036  g_loss:2.2107
# epoch:104  d_loss:0.3753  g_loss:2.0523
# epoch:105  d_loss:0.5378  g_loss:2.2322
# epoch:106  d_loss:0.3511  g_loss:2.4400
# epoch:107  d_loss:0.5610  g_loss:1.8870
# epoch:108  d_loss:0.6967  g_loss:2.1260
# epoch:109  d_loss:0.6286  g_loss:2.2647
# epoch:110  d_loss:0.6547  g_loss:2.1803
# epoch:111  d_loss:0.6689  g_loss:2.1119
# epoch:112  d_loss:0.8269  g_loss:1.6605
# epoch:113  d_loss:0.6161  g_loss:1.5681
# epoch:114  d_loss:0.6457  g_loss:1.5508
# epoch:115  d_loss:0.6672  g_loss:1.5099
# epoch:116  d_loss:0.6970  g_loss:1.4156
# epoch:117  d_loss:0.5570  g_loss:1.3092
# epoch:118  d_loss:0.3902  g_loss:1.5106
# epoch:119  d_loss:0.4294  g_loss:1.2668
# epoch:120  d_loss:0.3524  g_loss:1.4263
# epoch:121  d_loss:0.3764  g_loss:1.6611
# epoch:122  d_loss:0.2883  g_loss:1.4562
# epoch:123  d_loss:0.3384  g_loss:1.5804
# epoch:124  d_loss:0.3200  g_loss:1.6518
# epoch:125  d_loss:0.2992  g_loss:1.6765
# epoch:126  d_loss:0.2860  g_loss:1.6339
# epoch:127  d_loss:0.3229  g_loss:1.4700
# epoch:128  d_loss:0.3440  g_loss:1.2998
# epoch:129  d_loss:0.4470  g_loss:1.5311
# epoch:130  d_loss:0.3479  g_loss:1.6814
# epoch:131  d_loss:0.2835  g_loss:1.9199
# epoch:132  d_loss:0.3021  g_loss:1.9800
# epoch:133  d_loss:0.4700  g_loss:1.5909
# epoch:134  d_loss:0.4114  g_loss:1.5854
# epoch:135  d_loss:0.4666  g_loss:1.3801
# epoch:136  d_loss:0.4669  g_loss:1.6965
# epoch:137  d_loss:0.4210  g_loss:1.6930
# epoch:138  d_loss:0.5683  g_loss:1.9392
# epoch:139  d_loss:0.6451  g_loss:1.6865
# epoch:140  d_loss:0.6369  g_loss:1.5955
# epoch:141  d_loss:0.6451  g_loss:1.3852
# epoch:142  d_loss:0.7709  g_loss:1.6138
# epoch:143  d_loss:0.6573  g_loss:1.6317
# epoch:144  d_loss:0.6383  g_loss:1.5625
# epoch:145  d_loss:0.7062  g_loss:1.7729
# epoch:146  d_loss:0.5803  g_loss:2.2145
# epoch:147  d_loss:0.5483  g_loss:2.0685
# epoch:148  d_loss:0.5375  g_loss:1.9222
# epoch:149  d_loss:0.4715  g_loss:1.6017
# epoch:150  d_loss:0.4979  g_loss:1.5254
# epoch:151  d_loss:0.5351  g_loss:1.4345
# epoch:152  d_loss:0.3809  g_loss:1.6762
# epoch:153  d_loss:0.3904  g_loss:2.0203
# epoch:154  d_loss:0.3917  g_loss:2.0788
# epoch:155  d_loss:0.3505  g_loss:2.3813
# epoch:156  d_loss:0.5057  g_loss:2.0461
# epoch:157  d_loss:0.4461  g_loss:1.4534
# epoch:158  d_loss:0.3524  g_loss:1.4617
# epoch:159  d_loss:0.2784  g_loss:1.6548
# epoch:160  d_loss:0.3703  g_loss:1.9065
# epoch:161  d_loss:0.3784  g_loss:1.7179
# epoch:162  d_loss:0.3427  g_loss:2.2316
# epoch:163  d_loss:0.4424  g_loss:1.7384
# epoch:164  d_loss:0.4810  g_loss:2.1047
# epoch:165  d_loss:0.4601  g_loss:1.9115
# epoch:166  d_loss:0.5502  g_loss:1.8671
# epoch:167  d_loss:0.6131  g_loss:1.7596
# epoch:168  d_loss:0.6306  g_loss:1.8652
# epoch:169  d_loss:0.6314  g_loss:1.7623
# epoch:170  d_loss:0.5409  g_loss:1.7931
# epoch:171  d_loss:0.7369  g_loss:1.8370
# epoch:172  d_loss:0.5940  g_loss:1.4655
# epoch:173  d_loss:0.6334  g_loss:1.5668
# epoch:174  d_loss:0.6005  g_loss:1.7765
# epoch:175  d_loss:0.2948  g_loss:2.2899
# epoch:176  d_loss:0.5282  g_loss:2.3464
# epoch:177  d_loss:0.4916  g_loss:2.3485
# epoch:178  d_loss:0.4038  g_loss:2.0285
# epoch:179  d_loss:0.3752  g_loss:1.4642
# epoch:180  d_loss:0.3734  g_loss:1.6108
# epoch:181  d_loss:0.2955  g_loss:2.0143
# epoch:182  d_loss:0.3637  g_loss:2.2570
# epoch:183  d_loss:0.3964  g_loss:2.4813
# epoch:184  d_loss:0.3603  g_loss:2.3413
# epoch:185  d_loss:0.2937  g_loss:1.9905
# epoch:186  d_loss:0.3997  g_loss:2.4084
# epoch:187  d_loss:0.2368  g_loss:2.0259
# epoch:188  d_loss:0.4084  g_loss:2.1842
# epoch:189  d_loss:0.4648  g_loss:2.0791
# epoch:190  d_loss:0.3932  g_loss:2.7409
# epoch:191  d_loss:0.5734  g_loss:2.3181
# epoch:192  d_loss:0.5821  g_loss:1.7813
# epoch:193  d_loss:0.5461  g_loss:1.4268
# epoch:194  d_loss:0.5081  g_loss:1.4992
# epoch:195  d_loss:0.4312  g_loss:2.0853
# epoch:196  d_loss:0.4708  g_loss:2.6257
# epoch:197  d_loss:0.5380  g_loss:2.0746
# epoch:198  d_loss:0.7459  g_loss:1.7961
# epoch:199  d_loss:0.5873  g_loss:1.4391
# epoch:200  d_loss:0.5019  g_loss:1.5415
# epoch:201  d_loss:0.4308  g_loss:2.0923
# epoch:202  d_loss:0.4889  g_loss:2.4819
# epoch:203  d_loss:0.5753  g_loss:1.9069
# epoch:204  d_loss:0.3644  g_loss:1.7222
# epoch:205  d_loss:0.3195  g_loss:1.9817
# epoch:206  d_loss:0.4210  g_loss:2.2540
# epoch:207  d_loss:0.3003  g_loss:2.0103
# epoch:208  d_loss:0.2620  g_loss:2.0670
# epoch:209  d_loss:0.2017  g_loss:2.6425
# epoch:210  d_loss:0.2043  g_loss:2.8465
# epoch:211  d_loss:0.4281  g_loss:2.5045
# epoch:212  d_loss:0.2421  g_loss:2.5988
# epoch:213  d_loss:0.2433  g_loss:3.2216
# epoch:214  d_loss:0.2695  g_loss:3.0398
# epoch:215  d_loss:0.2758  g_loss:3.2662
# epoch:216  d_loss:0.4976  g_loss:2.8361
# epoch:217  d_loss:0.3369  g_loss:2.6031
# epoch:218  d_loss:0.4324  g_loss:2.3137
# epoch:219  d_loss:0.6355  g_loss:2.4450
# epoch:220  d_loss:0.6037  g_loss:2.7043
# epoch:221  d_loss:0.6916  g_loss:2.4629
# epoch:222  d_loss:0.7786  g_loss:2.1432
# epoch:223  d_loss:0.5162  g_loss:1.8372
# epoch:224  d_loss:0.5843  g_loss:2.2067
# epoch:225  d_loss:0.6818  g_loss:2.1082
# epoch:226  d_loss:0.6329  g_loss:2.2222
# epoch:227  d_loss:0.5434  g_loss:1.9415
# epoch:228  d_loss:0.7131  g_loss:2.2422
# epoch:229  d_loss:0.6140  g_loss:2.1042
# epoch:230  d_loss:0.4181  g_loss:2.2064
# epoch:231  d_loss:0.5115  g_loss:2.1119
# epoch:232  d_loss:0.3862  g_loss:2.3425
# epoch:233  d_loss:0.4114  g_loss:2.1550
# epoch:234  d_loss:0.4576  g_loss:1.9446
# epoch:235  d_loss:0.4235  g_loss:2.2971
# epoch:236  d_loss:0.4423  g_loss:1.9414
# epoch:237  d_loss:0.2062  g_loss:2.2965
# epoch:238  d_loss:0.3866  g_loss:2.1083
# epoch:239  d_loss:0.3207  g_loss:2.5033
# epoch:240  d_loss:0.3158  g_loss:2.2992
# epoch:241  d_loss:0.3541  g_loss:2.4482
# epoch:242  d_loss:0.3018  g_loss:2.6885
# epoch:243  d_loss:0.4250  g_loss:2.2657
# epoch:244  d_loss:0.3698  g_loss:2.1493
# epoch:245  d_loss:0.3421  g_loss:2.4351
# epoch:246  d_loss:0.3884  g_loss:2.3779
# epoch:247  d_loss:0.2905  g_loss:2.9056
# epoch:248  d_loss:0.3421  g_loss:2.4783
# epoch:249  d_loss:0.3301  g_loss:2.5728
# epoch:250  d_loss:0.3105  g_loss:2.4488
# epoch:251  d_loss:0.4278  g_loss:2.5026
# epoch:252  d_loss:0.3993  g_loss:2.5633
# epoch:253  d_loss:0.3257  g_loss:2.8274
# epoch:254  d_loss:0.3324  g_loss:2.5970
# epoch:255  d_loss:0.4068  g_loss:2.2765
# epoch:256  d_loss:0.5055  g_loss:2.0941
# epoch:257  d_loss:0.6181  g_loss:1.7734
# epoch:258  d_loss:0.4646  g_loss:1.5638
# epoch:259  d_loss:0.6014  g_loss:1.6642
# epoch:260  d_loss:0.6591  g_loss:2.2483
# epoch:261  d_loss:0.8402  g_loss:2.1703
# epoch:262  d_loss:0.6159  g_loss:1.7107
# epoch:263  d_loss:0.5951  g_loss:2.2447
# epoch:264  d_loss:0.6229  g_loss:2.1406
# epoch:265  d_loss:0.4937  g_loss:2.3900
# epoch:266  d_loss:0.8492  g_loss:2.3671
# epoch:267  d_loss:0.5875  g_loss:2.3531
# epoch:268  d_loss:0.3941  g_loss:3.4207
# epoch:269  d_loss:0.3512  g_loss:3.8791
# epoch:270  d_loss:0.3837  g_loss:3.3841
# epoch:271  d_loss:0.3236  g_loss:3.0207
# epoch:272  d_loss:0.2198  g_loss:2.3617
# epoch:273  d_loss:0.1672  g_loss:2.4264
# epoch:274  d_loss:0.1341  g_loss:3.0796
# epoch:275  d_loss:0.1991  g_loss:3.3084
# epoch:276  d_loss:0.0792  g_loss:3.7432
# epoch:277  d_loss:0.0920  g_loss:3.8478
# epoch:278  d_loss:0.2333  g_loss:3.6888
# epoch:279  d_loss:0.0799  g_loss:4.2605
# epoch:280  d_loss:0.2658  g_loss:3.3434
# epoch:281  d_loss:0.2083  g_loss:3.1394
# epoch:282  d_loss:0.0906  g_loss:3.6822
# epoch:283  d_loss:0.2342  g_loss:3.3105
# epoch:284  d_loss:0.3393  g_loss:2.9414
# epoch:285  d_loss:0.5345  g_loss:2.8900
# epoch:286  d_loss:0.3983  g_loss:3.5740
# epoch:287  d_loss:0.2364  g_loss:3.4095
# epoch:288  d_loss:0.4778  g_loss:2.9003
# epoch:289  d_loss:0.6573  g_loss:2.0045
# epoch:290  d_loss:0.6483  g_loss:1.9469
# epoch:291  d_loss:0.5601  g_loss:1.9829
# epoch:292  d_loss:0.6796  g_loss:2.1395
# epoch:293  d_loss:0.6236  g_loss:2.5327
# epoch:294  d_loss:0.7489  g_loss:2.4024
# epoch:295  d_loss:0.9035  g_loss:2.3947
# epoch:296  d_loss:0.7485  g_loss:1.9514
# epoch:297  d_loss:0.6080  g_loss:1.6172
# epoch:298  d_loss:0.5143  g_loss:1.7223
# epoch:299  d_loss:0.5457  g_loss:2.0398
# epoch:300  d_loss:0.4544  g_loss:2.6120
# epoch:301  d_loss:0.4183  g_loss:2.0424
# epoch:302  d_loss:0.4747  g_loss:2.5101
# epoch:303  d_loss:0.4137  g_loss:2.3437
# epoch:304  d_loss:0.4618  g_loss:1.7251
# epoch:305  d_loss:0.5063  g_loss:2.4627
# epoch:306  d_loss:0.4633  g_loss:2.0181
# epoch:307  d_loss:0.4402  g_loss:1.9547
# epoch:308  d_loss:0.2938  g_loss:2.1036
# epoch:309  d_loss:0.4042  g_loss:1.8726
# epoch:310  d_loss:0.5235  g_loss:2.1373
# epoch:311  d_loss:0.3778  g_loss:2.0449
# epoch:312  d_loss:0.4120  g_loss:1.9589
# epoch:313  d_loss:0.2826  g_loss:2.0675
# epoch:314  d_loss:0.5395  g_loss:2.0118
# epoch:315  d_loss:0.4286  g_loss:2.2003
# epoch:316  d_loss:0.5770  g_loss:2.2440
# epoch:317  d_loss:0.3672  g_loss:2.4318
# epoch:318  d_loss:0.3545  g_loss:2.8261
# epoch:319  d_loss:0.4739  g_loss:2.2044
# epoch:320  d_loss:0.5211  g_loss:2.1136
# epoch:321  d_loss:0.4810  g_loss:1.6588
# epoch:322  d_loss:0.3520  g_loss:2.0591
# epoch:323  d_loss:0.4593  g_loss:2.1280
# epoch:324  d_loss:0.3071  g_loss:2.3221
# epoch:325  d_loss:0.3875  g_loss:2.7304
# epoch:326  d_loss:0.4991  g_loss:2.6949
# epoch:327  d_loss:0.4352  g_loss:2.0471
# epoch:328  d_loss:0.4299  g_loss:1.9904
# epoch:329  d_loss:0.4677  g_loss:1.9565
# epoch:330  d_loss:0.4403  g_loss:2.2209
# epoch:331  d_loss:0.4854  g_loss:2.4218
# epoch:332  d_loss:0.4918  g_loss:2.3447
# epoch:333  d_loss:0.5118  g_loss:2.0076
# epoch:334  d_loss:0.3615  g_loss:2.1109
# epoch:335  d_loss:0.4913  g_loss:1.6563
# epoch:336  d_loss:0.4212  g_loss:1.6747
# epoch:337  d_loss:0.4261  g_loss:2.0251
# epoch:338  d_loss:0.3589  g_loss:1.9257
# epoch:339  d_loss:0.4315  g_loss:2.0241
# epoch:340  d_loss:0.3708  g_loss:2.1849
# epoch:341  d_loss:0.5091  g_loss:1.9270
# epoch:342  d_loss:0.4073  g_loss:1.9831
# epoch:343  d_loss:0.4688  g_loss:1.9730
# epoch:344  d_loss:0.4892  g_loss:1.9154
# epoch:345  d_loss:0.5453  g_loss:1.9354
# epoch:346  d_loss:0.3335  g_loss:1.9986
# epoch:347  d_loss:0.2960  g_loss:2.0915
# epoch:348  d_loss:0.3408  g_loss:2.1820
# epoch:349  d_loss:0.4124  g_loss:2.0780
# epoch:350  d_loss:0.3998  g_loss:2.2866
# epoch:351  d_loss:0.3329  g_loss:1.9175
# epoch:352  d_loss:0.2828  g_loss:2.2137
# epoch:353  d_loss:0.3237  g_loss:2.3970
# epoch:354  d_loss:0.4047  g_loss:2.6776
# epoch:355  d_loss:0.3089  g_loss:2.8125
# epoch:356  d_loss:0.3809  g_loss:2.4999
# epoch:357  d_loss:0.2660  g_loss:2.8760
# epoch:358  d_loss:0.4483  g_loss:2.3344
# epoch:359  d_loss:0.3490  g_loss:2.4198
# epoch:360  d_loss:0.4771  g_loss:2.0609
# epoch:361  d_loss:0.3644  g_loss:3.0066
# epoch:362  d_loss:0.3853  g_loss:3.2692
# epoch:363  d_loss:0.2778  g_loss:3.5281
# epoch:364  d_loss:0.3420  g_loss:2.8404
# epoch:365  d_loss:0.4182  g_loss:2.2608
# epoch:366  d_loss:0.4580  g_loss:2.2411
# epoch:367  d_loss:0.3921  g_loss:2.1476
# epoch:368  d_loss:0.4252  g_loss:2.3912
# epoch:369  d_loss:0.3079  g_loss:2.9279
# epoch:370  d_loss:0.4020  g_loss:2.8535
# epoch:371  d_loss:0.3652  g_loss:2.4877
# epoch:372  d_loss:0.2456  g_loss:2.3252
# epoch:373  d_loss:0.4809  g_loss:2.4969
# epoch:374  d_loss:0.4047  g_loss:1.8791
# epoch:375  d_loss:0.4866  g_loss:1.7040
# epoch:376  d_loss:0.2889  g_loss:2.2973
# epoch:377  d_loss:0.3193  g_loss:2.7073
# epoch:378  d_loss:0.2703  g_loss:2.8648
# epoch:379  d_loss:0.3575  g_loss:2.3817
# epoch:380  d_loss:0.3256  g_loss:2.1559
# epoch:381  d_loss:0.3367  g_loss:2.3788
# epoch:382  d_loss:0.4282  g_loss:2.2443
# epoch:383  d_loss:0.3073  g_loss:2.2198
# epoch:384  d_loss:0.3940  g_loss:2.5255
# epoch:385  d_loss:0.2772  g_loss:2.6884
# epoch:386  d_loss:0.2373  g_loss:2.9204
# epoch:387  d_loss:0.3055  g_loss:2.6040
# epoch:388  d_loss:0.3832  g_loss:2.6282
# epoch:389  d_loss:0.3219  g_loss:2.0918
# epoch:390  d_loss:0.2992  g_loss:2.3019
# epoch:391  d_loss:0.3658  g_loss:2.1041
# epoch:392  d_loss:0.2175  g_loss:2.6645
# epoch:393  d_loss:0.2405  g_loss:2.8090
# epoch:394  d_loss:0.2935  g_loss:2.4082
# epoch:395  d_loss:0.2784  g_loss:2.6069
# epoch:396  d_loss:0.2841  g_loss:2.7897
# epoch:397  d_loss:0.3276  g_loss:2.4483
# epoch:398  d_loss:0.4056  g_loss:1.8405
# epoch:399  d_loss:0.3770  g_loss:2.1797
# epoch:400  d_loss:0.3145  g_loss:2.0020
# epoch:401  d_loss:0.2889  g_loss:2.4101
# epoch:402  d_loss:0.2882  g_loss:2.4300
# epoch:403  d_loss:0.3361  g_loss:2.1903
# epoch:404  d_loss:0.3278  g_loss:2.5880
# epoch:405  d_loss:0.3332  g_loss:2.0141
# epoch:406  d_loss:0.4429  g_loss:1.5426
# epoch:407  d_loss:0.4283  g_loss:2.0188
# epoch:408  d_loss:0.3341  g_loss:1.9509
# epoch:409  d_loss:0.3202  g_loss:2.8421
# epoch:410  d_loss:0.3313  g_loss:2.8079
# epoch:411  d_loss:0.4416  g_loss:2.5837
# epoch:412  d_loss:0.2786  g_loss:2.2404
# epoch:413  d_loss:0.3079  g_loss:2.0954
# epoch:414  d_loss:0.5207  g_loss:1.6992
# epoch:415  d_loss:0.5198  g_loss:1.7152
# epoch:416  d_loss:0.3663  g_loss:1.7409
# epoch:417  d_loss:0.3378  g_loss:2.2124
# epoch:418  d_loss:0.3467  g_loss:2.3092
# epoch:419  d_loss:0.2625  g_loss:2.9027
# epoch:420  d_loss:0.3758  g_loss:2.1671
# epoch:421  d_loss:0.4005  g_loss:2.1685
# epoch:422  d_loss:0.4256  g_loss:1.6958
# epoch:423  d_loss:0.3191  g_loss:2.0318
# epoch:424  d_loss:0.3129  g_loss:2.3088
# epoch:425  d_loss:0.3272  g_loss:2.5000
# epoch:426  d_loss:0.3967  g_loss:2.0451
# epoch:427  d_loss:0.3560  g_loss:2.2332
# epoch:428  d_loss:0.3592  g_loss:1.4734
# epoch:429  d_loss:0.3594  g_loss:2.0456
# epoch:430  d_loss:0.3149  g_loss:2.1526
# epoch:431  d_loss:0.3289  g_loss:2.1235
# epoch:432  d_loss:0.3570  g_loss:2.0252
# epoch:433  d_loss:0.2518  g_loss:2.2410
# epoch:434  d_loss:0.3124  g_loss:2.3154
# epoch:435  d_loss:0.2898  g_loss:2.1164
# epoch:436  d_loss:0.3523  g_loss:1.9378
# epoch:437  d_loss:0.3590  g_loss:2.1704
# epoch:438  d_loss:0.2581  g_loss:2.0616
# epoch:439  d_loss:0.3069  g_loss:2.3412
# epoch:440  d_loss:0.3336  g_loss:2.5323
# epoch:441  d_loss:0.2364  g_loss:2.2315
# epoch:442  d_loss:0.2190  g_loss:2.5716
# epoch:443  d_loss:0.1579  g_loss:2.6093
# epoch:444  d_loss:0.2951  g_loss:2.4174
# epoch:445  d_loss:0.2320  g_loss:2.5327
# epoch:446  d_loss:0.3821  g_loss:2.1411
# epoch:447  d_loss:0.2301  g_loss:2.3122
# epoch:448  d_loss:0.2594  g_loss:2.9715
# epoch:449  d_loss:0.3237  g_loss:2.9924
# epoch:450  d_loss:0.4800  g_loss:2.6733
# epoch:451  d_loss:0.4159  g_loss:1.7024
# epoch:452  d_loss:0.4065  g_loss:2.1940
# epoch:453  d_loss:0.3014  g_loss:3.5766
# epoch:454  d_loss:0.2876  g_loss:3.1621
# epoch:455  d_loss:0.2222  g_loss:2.8779
# epoch:456  d_loss:0.3724  g_loss:2.1958
# epoch:457  d_loss:0.3797  g_loss:1.6263
# epoch:458  d_loss:0.3487  g_loss:2.0309
# epoch:459  d_loss:0.2943  g_loss:2.2002
# epoch:460  d_loss:0.4178  g_loss:2.4543
# epoch:461  d_loss:0.2986  g_loss:2.3148
# epoch:462  d_loss:0.2504  g_loss:2.5005
# epoch:463  d_loss:0.2735  g_loss:2.4788
# epoch:464  d_loss:0.3186  g_loss:2.2667
# epoch:465  d_loss:0.4769  g_loss:1.7825
# epoch:466  d_loss:0.4471  g_loss:2.2016
# epoch:467  d_loss:0.1714  g_loss:2.6010
# epoch:468  d_loss:0.4332  g_loss:2.7057
# epoch:469  d_loss:0.4249  g_loss:2.7466
# epoch:470  d_loss:0.2644  g_loss:2.3602
# epoch:471  d_loss:0.2372  g_loss:1.9873
# epoch:472  d_loss:0.3748  g_loss:2.4653
# epoch:473  d_loss:0.2861  g_loss:2.6967
# epoch:474  d_loss:0.3428  g_loss:2.6956
# epoch:475  d_loss:0.4456  g_loss:2.6188
# epoch:476  d_loss:0.2745  g_loss:2.3478
# epoch:477  d_loss:0.3101  g_loss:2.1948
# epoch:478  d_loss:0.3190  g_loss:2.0353
# epoch:479  d_loss:0.3846  g_loss:2.1896
# epoch:480  d_loss:0.2196  g_loss:2.4362
# epoch:481  d_loss:0.3658  g_loss:1.7145
# epoch:482  d_loss:0.3517  g_loss:2.0832
# epoch:483  d_loss:0.2989  g_loss:2.7420
# epoch:484  d_loss:0.2754  g_loss:2.5256
# epoch:485  d_loss:0.2982  g_loss:2.7063
# epoch:486  d_loss:0.2489  g_loss:2.8520
# epoch:487  d_loss:0.2638  g_loss:2.1279
# epoch:488  d_loss:0.2979  g_loss:2.4525
# epoch:489  d_loss:0.2028  g_loss:2.4507
# epoch:490  d_loss:0.1871  g_loss:2.6032
# epoch:491  d_loss:0.2582  g_loss:2.6175
# epoch:492  d_loss:0.2396  g_loss:2.6567
# epoch:493  d_loss:0.2785  g_loss:2.3562
# epoch:494  d_loss:0.2197  g_loss:2.7353
# epoch:495  d_loss:0.2480  g_loss:2.5960
# epoch:496  d_loss:0.3128  g_loss:2.6372
# epoch:497  d_loss:0.2486  g_loss:2.3024
# epoch:498  d_loss:0.2810  g_loss:2.4635
# epoch:499  d_loss:0.2191  g_loss:2.9722
# epoch:500  d_loss:0.2069  g_loss:2.9352
# epoch:501  d_loss:0.3280  g_loss:2.7581
# epoch:502  d_loss:0.2478  g_loss:2.2933
# epoch:503  d_loss:0.3376  g_loss:2.5509
# epoch:504  d_loss:0.2621  g_loss:3.0230
# epoch:505  d_loss:0.1266  g_loss:3.1823
# epoch:506  d_loss:0.2496  g_loss:2.6255
# epoch:507  d_loss:0.1868  g_loss:2.8395
# epoch:508  d_loss:0.1791  g_loss:2.9274
# epoch:509  d_loss:0.2425  g_loss:2.1536
# epoch:510  d_loss:0.1859  g_loss:2.9343
# epoch:511  d_loss:0.1813  g_loss:2.9861
# epoch:512  d_loss:0.1416  g_loss:3.0656
# epoch:513  d_loss:0.2317  g_loss:2.4970
# epoch:514  d_loss:0.2156  g_loss:2.6806
# epoch:515  d_loss:0.2033  g_loss:2.5915
# epoch:516  d_loss:0.2920  g_loss:2.3552
# epoch:517  d_loss:0.2154  g_loss:2.6876
# epoch:518  d_loss:0.3016  g_loss:2.8444
# epoch:519  d_loss:0.2745  g_loss:2.6805
# epoch:520  d_loss:0.2274  g_loss:2.3038
# epoch:521  d_loss:0.2173  g_loss:2.5220
# epoch:522  d_loss:0.3050  g_loss:2.5417
# epoch:523  d_loss:0.2578  g_loss:2.3991
# epoch:524  d_loss:0.2561  g_loss:2.5002
# epoch:525  d_loss:0.3826  g_loss:2.0160
# epoch:526  d_loss:0.3292  g_loss:3.0945
# epoch:527  d_loss:0.3602  g_loss:2.6799
# epoch:528  d_loss:0.3638  g_loss:2.1721
# epoch:529  d_loss:0.2246  g_loss:2.6572
# epoch:530  d_loss:0.2643  g_loss:2.8319
# epoch:531  d_loss:0.2284  g_loss:2.3929
# epoch:532  d_loss:0.2327  g_loss:2.6762
# epoch:533  d_loss:0.2183  g_loss:3.0320
# epoch:534  d_loss:0.2222  g_loss:2.8479
# epoch:535  d_loss:0.2575  g_loss:2.7211
# epoch:536  d_loss:0.3061  g_loss:2.1784
# epoch:537  d_loss:0.2208  g_loss:2.4804
# epoch:538  d_loss:0.1632  g_loss:3.1710
# epoch:539  d_loss:0.1434  g_loss:3.1848
# epoch:540  d_loss:0.1563  g_loss:3.7576
# epoch:541  d_loss:0.1722  g_loss:2.6109
# epoch:542  d_loss:0.2575  g_loss:2.1970
# epoch:543  d_loss:0.1936  g_loss:2.9341
# epoch:544  d_loss:0.0855  g_loss:3.9163
# epoch:545  d_loss:0.1281  g_loss:3.9186
# epoch:546  d_loss:0.1649  g_loss:3.2381
# epoch:547  d_loss:0.1618  g_loss:2.7060
# epoch:548  d_loss:0.1100  g_loss:2.7600
# epoch:549  d_loss:0.2356  g_loss:2.4997
# epoch:550  d_loss:0.1405  g_loss:2.6936
# epoch:551  d_loss:0.1392  g_loss:2.4663
# epoch:552  d_loss:0.1864  g_loss:2.7538
# epoch:553  d_loss:0.2191  g_loss:2.9547
# epoch:554  d_loss:0.1583  g_loss:3.0925
# epoch:555  d_loss:0.1968  g_loss:2.9111
# epoch:556  d_loss:0.1114  g_loss:3.2993
# epoch:557  d_loss:0.1806  g_loss:2.6308
# epoch:558  d_loss:0.1841  g_loss:2.5289
# epoch:559  d_loss:0.1768  g_loss:3.0477
# epoch:560  d_loss:0.2078  g_loss:3.0553
# epoch:561  d_loss:0.1090  g_loss:3.0718
# epoch:562  d_loss:0.2119  g_loss:2.6081
# epoch:563  d_loss:0.2798  g_loss:2.8676
# epoch:564  d_loss:0.2719  g_loss:2.6284
# epoch:565  d_loss:0.2003  g_loss:2.6918
# epoch:566  d_loss:0.2494  g_loss:3.5637
# epoch:567  d_loss:0.1967  g_loss:3.1750
# epoch:568  d_loss:0.2139  g_loss:2.4073
# epoch:569  d_loss:0.2278  g_loss:2.4064
# epoch:570  d_loss:0.2919  g_loss:2.6773
# epoch:571  d_loss:0.1827  g_loss:3.4623
# epoch:572  d_loss:0.2320  g_loss:3.0696
# epoch:573  d_loss:0.2419  g_loss:2.7934
# epoch:574  d_loss:0.1820  g_loss:2.5718
# epoch:575  d_loss:0.3755  g_loss:2.3654
# epoch:576  d_loss:0.4397  g_loss:2.6104
# epoch:577  d_loss:0.2288  g_loss:3.4392
# epoch:578  d_loss:0.2420  g_loss:3.0401
# epoch:579  d_loss:0.4619  g_loss:2.0164
# epoch:580  d_loss:0.3760  g_loss:1.8191
# epoch:581  d_loss:0.1157  g_loss:2.7173
# epoch:582  d_loss:0.1540  g_loss:2.9916
# epoch:583  d_loss:0.3041  g_loss:2.6935
# epoch:584  d_loss:0.2767  g_loss:2.7629
# epoch:585  d_loss:0.1566  g_loss:2.5911
# epoch:586  d_loss:0.1340  g_loss:2.5655
# epoch:587  d_loss:0.1322  g_loss:2.9339
# epoch:588  d_loss:0.1231  g_loss:2.8129
# epoch:589  d_loss:0.1438  g_loss:3.4295
# epoch:590  d_loss:0.0986  g_loss:3.1535
# epoch:591  d_loss:0.2008  g_loss:2.4671
# epoch:592  d_loss:0.1914  g_loss:2.6349
# epoch:593  d_loss:0.1317  g_loss:3.3615
# epoch:594  d_loss:0.1400  g_loss:3.8602
# epoch:595  d_loss:0.2990  g_loss:3.2038
# epoch:596  d_loss:0.2294  g_loss:2.5635
# epoch:597  d_loss:0.2914  g_loss:2.0718
# epoch:598  d_loss:0.2503  g_loss:3.0440
# epoch:599  d_loss:0.1669  g_loss:2.7150
# epoch:600  d_loss:0.2142  g_loss:2.5128
# epoch:601  d_loss:0.1460  g_loss:3.1521
# epoch:602  d_loss:0.1637  g_loss:3.3049
# epoch:603  d_loss:0.2132  g_loss:2.1458
# epoch:604  d_loss:0.2791  g_loss:3.1249
# epoch:605  d_loss:0.1133  g_loss:3.2802
# epoch:606  d_loss:0.2799  g_loss:2.7120
# epoch:607  d_loss:0.2836  g_loss:2.0845
# epoch:608  d_loss:0.2559  g_loss:2.0494
# epoch:609  d_loss:0.3411  g_loss:1.7962
# epoch:610  d_loss:0.2083  g_loss:2.0471
# epoch:611  d_loss:0.3632  g_loss:2.5075
# epoch:612  d_loss:0.3233  g_loss:2.4193
# epoch:613  d_loss:0.3919  g_loss:1.6808
# epoch:614  d_loss:0.2220  g_loss:2.8281
# epoch:615  d_loss:0.2588  g_loss:2.2434
# epoch:616  d_loss:0.1735  g_loss:3.2471
# epoch:617  d_loss:0.1947  g_loss:1.9012
# epoch:618  d_loss:0.2261  g_loss:2.1187
# epoch:619  d_loss:0.2995  g_loss:1.9793
# epoch:620  d_loss:0.2202  g_loss:1.8932
# epoch:621  d_loss:0.2636  g_loss:2.1934
# epoch:622  d_loss:0.2725  g_loss:2.5607
# epoch:623  d_loss:0.4833  g_loss:2.1025
# epoch:624  d_loss:0.3093  g_loss:2.6652
# epoch:625  d_loss:0.3558  g_loss:2.4787
# epoch:626  d_loss:0.2045  g_loss:2.2234
# epoch:627  d_loss:0.5196  g_loss:2.1415
# epoch:628  d_loss:0.6482  g_loss:2.0244
# epoch:629  d_loss:0.3133  g_loss:3.0124
# epoch:630  d_loss:0.2951  g_loss:3.4481
# epoch:631  d_loss:0.6060  g_loss:2.0834
# epoch:632  d_loss:0.4044  g_loss:1.6410
# epoch:633  d_loss:0.3070  g_loss:2.6018
# epoch:634  d_loss:0.2298  g_loss:3.7720
# epoch:635  d_loss:0.4952  g_loss:3.1907
# epoch:636  d_loss:0.6256  g_loss:2.4589
# epoch:637  d_loss:0.4131  g_loss:2.8362
# epoch:638  d_loss:0.4067  g_loss:3.4056
# epoch:639  d_loss:0.6473  g_loss:3.1898
# epoch:640  d_loss:0.5640  g_loss:2.9109
# epoch:641  d_loss:1.0147  g_loss:1.6215
# epoch:642  d_loss:0.6868  g_loss:1.2895
# epoch:643  d_loss:0.6927  g_loss:1.8635
# epoch:644  d_loss:0.7405  g_loss:2.8621
# epoch:645  d_loss:1.1243  g_loss:2.2347
# epoch:646  d_loss:0.5172  g_loss:1.9192
# epoch:647  d_loss:0.8176  g_loss:1.3771
# epoch:648  d_loss:0.6688  g_loss:1.4061
# epoch:649  d_loss:0.5523  g_loss:2.1520
# epoch:650  d_loss:0.9057  g_loss:2.1379
# epoch:651  d_loss:0.6988  g_loss:2.4369
# epoch:652  d_loss:1.1200  g_loss:1.9028
# epoch:653  d_loss:0.6812  g_loss:1.6147
# epoch:654  d_loss:0.6178  g_loss:1.3154
# epoch:655  d_loss:0.9056  g_loss:1.5365
# epoch:656  d_loss:0.9747  g_loss:1.7230
# epoch:657  d_loss:0.8567  g_loss:1.3884
# epoch:658  d_loss:0.6749  g_loss:1.6129
# epoch:659  d_loss:0.8644  g_loss:1.7700
# epoch:660  d_loss:0.4156  g_loss:2.7153
# epoch:661  d_loss:0.2114  g_loss:3.5278
# epoch:662  d_loss:0.1760  g_loss:3.6832
# epoch:663  d_loss:0.1862  g_loss:3.2610
# epoch:664  d_loss:0.5317  g_loss:3.0531
# epoch:665  d_loss:0.8838  g_loss:2.5235
# epoch:666  d_loss:0.5809  g_loss:1.9879
# epoch:667  d_loss:0.6587  g_loss:2.1830
# epoch:668  d_loss:0.7041  g_loss:2.3865
# epoch:669  d_loss:0.4509  g_loss:3.0150
# epoch:670  d_loss:0.6306  g_loss:3.0736
# epoch:671  d_loss:0.4962  g_loss:2.6534
# epoch:672  d_loss:0.8555  g_loss:2.5879
# epoch:673  d_loss:0.6046  g_loss:2.2926
# epoch:674  d_loss:0.5172  g_loss:2.1418
# epoch:675  d_loss:0.3638  g_loss:2.0720
# epoch:676  d_loss:0.4382  g_loss:1.5599
# epoch:677  d_loss:0.4737  g_loss:1.8768
# epoch:678  d_loss:0.6863  g_loss:1.4167
# epoch:679  d_loss:0.6767  g_loss:1.2906
# epoch:680  d_loss:0.6856  g_loss:1.2884
# epoch:681  d_loss:0.3997  g_loss:1.8824
# epoch:682  d_loss:0.5072  g_loss:2.2529
# epoch:683  d_loss:0.4235  g_loss:1.9211
# epoch:684  d_loss:0.5607  g_loss:1.7403
# epoch:685  d_loss:0.4265  g_loss:1.8550
# epoch:686  d_loss:0.5384  g_loss:1.8294
# epoch:687  d_loss:0.4329  g_loss:2.2498
# epoch:688  d_loss:0.5342  g_loss:2.4166
# epoch:689  d_loss:0.4525  g_loss:2.3026
# epoch:690  d_loss:0.3843  g_loss:1.7950
# epoch:691  d_loss:0.3579  g_loss:1.5818
# epoch:692  d_loss:0.2989  g_loss:1.5636
# epoch:693  d_loss:0.3359  g_loss:1.8176
# epoch:694  d_loss:0.4358  g_loss:2.3074
# epoch:695  d_loss:0.4472  g_loss:2.3081
# epoch:696  d_loss:0.3092  g_loss:2.9291
# epoch:697  d_loss:0.6212  g_loss:2.0058
# epoch:698  d_loss:0.6320  g_loss:1.5971
# epoch:699  d_loss:0.4168  g_loss:1.7708
# epoch:700  d_loss:0.3596  g_loss:2.3111
# epoch:701  d_loss:0.2742  g_loss:2.7849
# epoch:702  d_loss:0.2488  g_loss:3.1673
# epoch:703  d_loss:0.2176  g_loss:3.4824
# epoch:704  d_loss:0.2420  g_loss:2.7516
# epoch:705  d_loss:0.1983  g_loss:2.8378
# epoch:706  d_loss:0.2515  g_loss:2.2324
# epoch:707  d_loss:0.2030  g_loss:2.4437
# epoch:708  d_loss:0.2248  g_loss:2.6024
# epoch:709  d_loss:0.3026  g_loss:2.1491
# epoch:710  d_loss:0.3088  g_loss:2.7476
# epoch:711  d_loss:0.3750  g_loss:2.0805
# epoch:712  d_loss:0.3398  g_loss:2.1356
# epoch:713  d_loss:0.5217  g_loss:2.1681
# epoch:714  d_loss:0.3334  g_loss:2.0162
# epoch:715  d_loss:0.3838  g_loss:1.9634
# epoch:716  d_loss:0.3180  g_loss:1.7326
# epoch:717  d_loss:0.2863  g_loss:2.3489
# epoch:718  d_loss:0.3184  g_loss:2.3693
# epoch:719  d_loss:0.3315  g_loss:2.2375
# epoch:720  d_loss:0.2936  g_loss:1.9987
# epoch:721  d_loss:0.2861  g_loss:2.0612
# epoch:722  d_loss:0.2848  g_loss:2.1656
# epoch:723  d_loss:0.3381  g_loss:2.5506
# epoch:724  d_loss:0.1842  g_loss:2.7737
# epoch:725  d_loss:0.2691  g_loss:2.6343
# epoch:726  d_loss:0.2732  g_loss:2.4276
# epoch:727  d_loss:0.3353  g_loss:1.9973
# epoch:728  d_loss:0.5459  g_loss:2.0546
# epoch:729  d_loss:0.3250  g_loss:2.3127
# epoch:730  d_loss:0.4409  g_loss:1.8154
# epoch:731  d_loss:0.4309  g_loss:1.9942
# epoch:732  d_loss:0.4154  g_loss:1.6351
# epoch:733  d_loss:0.5124  g_loss:1.6798
# epoch:734  d_loss:0.2870  g_loss:2.4941
# epoch:735  d_loss:0.3921  g_loss:2.0483
# epoch:736  d_loss:0.4517  g_loss:2.0452
# epoch:737  d_loss:0.4230  g_loss:2.0798
# epoch:738  d_loss:0.5664  g_loss:1.9625
# epoch:739  d_loss:0.5702  g_loss:1.4623
# epoch:740  d_loss:0.3489  g_loss:2.1714
# epoch:741  d_loss:0.3634  g_loss:2.0851
# epoch:742  d_loss:0.5120  g_loss:1.9709
# epoch:743  d_loss:0.4029  g_loss:1.8240
# epoch:744  d_loss:0.3856  g_loss:1.9454
# epoch:745  d_loss:0.3189  g_loss:2.1405
# epoch:746  d_loss:0.3405  g_loss:2.4107
# epoch:747  d_loss:0.4897  g_loss:2.2054
# epoch:748  d_loss:0.2636  g_loss:2.3428
# epoch:749  d_loss:0.3689  g_loss:2.1466
# epoch:750  d_loss:0.3717  g_loss:2.3097
# epoch:751  d_loss:0.3373  g_loss:2.1527
# epoch:752  d_loss:0.2315  g_loss:2.2514
# epoch:753  d_loss:0.2729  g_loss:2.8877
# epoch:754  d_loss:0.3140  g_loss:2.6251
# epoch:755  d_loss:0.3545  g_loss:2.3905
# epoch:756  d_loss:0.2589  g_loss:2.0836
# epoch:757  d_loss:0.3452  g_loss:2.1689
# epoch:758  d_loss:0.2841  g_loss:2.5204
# epoch:759  d_loss:0.4831  g_loss:2.0380
# epoch:760  d_loss:0.2101  g_loss:2.3358
# epoch:761  d_loss:0.2573  g_loss:2.5520
# epoch:762  d_loss:0.3557  g_loss:2.1931
# epoch:763  d_loss:0.2863  g_loss:2.6906
# epoch:764  d_loss:0.4352  g_loss:1.5461
# epoch:765  d_loss:0.3951  g_loss:2.0618
# epoch:766  d_loss:0.4216  g_loss:1.8097
# epoch:767  d_loss:0.4484  g_loss:1.8838
# epoch:768  d_loss:0.2842  g_loss:2.5303
# epoch:769  d_loss:0.4954  g_loss:2.2150
# epoch:770  d_loss:0.5838  g_loss:1.7335
# epoch:771  d_loss:0.4063  g_loss:2.1966
# epoch:772  d_loss:0.3966  g_loss:1.6346
# epoch:773  d_loss:0.4891  g_loss:1.7306
# epoch:774  d_loss:0.7771  g_loss:1.7003
# epoch:775  d_loss:0.5669  g_loss:1.3478
# epoch:776  d_loss:0.7414  g_loss:1.8219
# epoch:777  d_loss:1.0887  g_loss:1.8039
# epoch:778  d_loss:0.8946  g_loss:1.8344
# epoch:779  d_loss:0.5311  g_loss:1.3712
# epoch:780  d_loss:0.6025  g_loss:1.6325
# epoch:781  d_loss:0.6945  g_loss:1.5359
# epoch:782  d_loss:0.4582  g_loss:1.8017
# epoch:783  d_loss:0.5965  g_loss:1.7272
# epoch:784  d_loss:0.3807  g_loss:1.9995
# epoch:785  d_loss:0.5965  g_loss:1.5882
# epoch:786  d_loss:0.6208  g_loss:1.3826
# epoch:787  d_loss:0.3065  g_loss:1.5797
# epoch:788  d_loss:0.3813  g_loss:1.6143
# epoch:789  d_loss:0.3844  g_loss:1.7496
# epoch:790  d_loss:0.5682  g_loss:2.1404
# epoch:791  d_loss:0.5206  g_loss:2.0718
# epoch:792  d_loss:0.4067  g_loss:2.0842
# epoch:793  d_loss:0.3739  g_loss:1.9345
# epoch:794  d_loss:0.2229  g_loss:1.9032
# epoch:795  d_loss:0.1607  g_loss:2.3877
# epoch:796  d_loss:0.2325  g_loss:2.4566
# epoch:797  d_loss:0.2780  g_loss:2.1654
# epoch:798  d_loss:0.2746  g_loss:2.4272
# epoch:799  d_loss:0.3701  g_loss:2.5054
# epoch:800  d_loss:0.2869  g_loss:2.6173
# epoch:801  d_loss:1.0821  g_loss:2.2359
# epoch:802  d_loss:0.5233  g_loss:1.7068
# epoch:803  d_loss:0.8671  g_loss:1.4769
# epoch:804  d_loss:0.7796  g_loss:1.6921
# epoch:805  d_loss:0.8817  g_loss:1.9687
# epoch:806  d_loss:0.7637  g_loss:2.8055
# epoch:807  d_loss:0.6659  g_loss:3.7075
# epoch:808  d_loss:0.5206  g_loss:3.8207
# epoch:809  d_loss:0.6137  g_loss:3.7272
# epoch:810  d_loss:0.2923  g_loss:3.5861
# epoch:811  d_loss:0.2112  g_loss:3.6479
# epoch:812  d_loss:0.1953  g_loss:4.1234
# epoch:813  d_loss:0.4005  g_loss:4.3790
# epoch:814  d_loss:0.3329  g_loss:4.2173
# epoch:815  d_loss:0.2447  g_loss:5.0394
# epoch:816  d_loss:0.3028  g_loss:4.3022
# epoch:817  d_loss:0.2411  g_loss:3.6554
# epoch:818  d_loss:0.3226  g_loss:2.7186
# epoch:819  d_loss:0.3450  g_loss:2.6018
# epoch:820  d_loss:0.4098  g_loss:1.9441
# epoch:821  d_loss:0.3880  g_loss:1.9575
# epoch:822  d_loss:0.3667  g_loss:2.4556
# epoch:823  d_loss:0.3819  g_loss:2.4809
# epoch:824  d_loss:0.4068  g_loss:2.5850
# epoch:825  d_loss:0.3268  g_loss:2.5376
# epoch:826  d_loss:0.2562  g_loss:2.2665
# epoch:827  d_loss:0.3130  g_loss:2.4174
# epoch:828  d_loss:0.3044  g_loss:2.4700
# epoch:829  d_loss:0.3361  g_loss:2.3513
# epoch:830  d_loss:0.2311  g_loss:2.2883
# epoch:831  d_loss:0.2819  g_loss:2.3527
# epoch:832  d_loss:0.1757  g_loss:3.0639
# epoch:833  d_loss:0.1386  g_loss:3.7046
# epoch:834  d_loss:0.1226  g_loss:3.2303
# epoch:835  d_loss:0.1351  g_loss:3.6343
# epoch:836  d_loss:0.0648  g_loss:3.8655
# epoch:837  d_loss:0.1308  g_loss:3.9532
# epoch:838  d_loss:0.1929  g_loss:4.3968
# epoch:839  d_loss:0.2003  g_loss:4.8208
# epoch:840  d_loss:0.1532  g_loss:5.2686
# epoch:841  d_loss:0.1890  g_loss:5.2072
# epoch:842  d_loss:0.3246  g_loss:3.8115
# epoch:843  d_loss:0.2860  g_loss:3.2480
# epoch:844  d_loss:0.8624  g_loss:2.9868
# epoch:845  d_loss:0.6567  g_loss:3.6593
# epoch:846  d_loss:0.9597  g_loss:3.1935
# epoch:847  d_loss:1.1600  g_loss:1.8110
# epoch:848  d_loss:0.9263  g_loss:1.9002
# epoch:849  d_loss:0.7111  g_loss:1.9361
# epoch:850  d_loss:0.5095  g_loss:2.6200
# epoch:851  d_loss:0.5065  g_loss:2.5439
# epoch:852  d_loss:0.4093  g_loss:3.0694
# epoch:853  d_loss:0.2628  g_loss:3.8489
# epoch:854  d_loss:0.3513  g_loss:4.3050
# epoch:855  d_loss:0.5003  g_loss:3.4888
# epoch:856  d_loss:0.2517  g_loss:3.7525
# epoch:857  d_loss:0.2799  g_loss:3.6334
# epoch:858  d_loss:0.2279  g_loss:3.9355
# epoch:859  d_loss:0.3020  g_loss:3.7384
# epoch:860  d_loss:0.4341  g_loss:3.2623
# epoch:861  d_loss:0.2686  g_loss:2.9473
# epoch:862  d_loss:0.2603  g_loss:2.5325
# epoch:863  d_loss:0.3563  g_loss:2.3664
# epoch:864  d_loss:0.2819  g_loss:2.2998
# epoch:865  d_loss:0.4022  g_loss:1.9821
# epoch:866  d_loss:0.4426  g_loss:1.7933
# epoch:867  d_loss:0.3180  g_loss:2.2485
# epoch:868  d_loss:0.4534  g_loss:2.0920
# epoch:869  d_loss:0.4819  g_loss:1.8030
# epoch:870  d_loss:0.5330  g_loss:1.5985
# epoch:871  d_loss:0.4401  g_loss:1.7399
# epoch:872  d_loss:0.5049  g_loss:1.7467
# epoch:873  d_loss:0.3693  g_loss:2.0256
# epoch:874  d_loss:0.3600  g_loss:2.2381
# epoch:875  d_loss:0.2039  g_loss:2.4627
# epoch:876  d_loss:0.2408  g_loss:2.6263
# epoch:877  d_loss:0.2745  g_loss:2.4015
# epoch:878  d_loss:0.2750  g_loss:2.5668
# epoch:879  d_loss:0.2212  g_loss:2.3689
# epoch:880  d_loss:0.1645  g_loss:2.5424
# epoch:881  d_loss:0.2821  g_loss:2.4280
# epoch:882  d_loss:0.1924  g_loss:2.7614
# epoch:883  d_loss:0.2721  g_loss:3.1228
# epoch:884  d_loss:0.2098  g_loss:3.0358
# epoch:885  d_loss:0.2386  g_loss:3.1253
# epoch:886  d_loss:0.3131  g_loss:3.0345
# epoch:887  d_loss:0.3627  g_loss:2.2929
# epoch:888  d_loss:0.4278  g_loss:2.3487
# epoch:889  d_loss:0.3221  g_loss:1.9591
# epoch:890  d_loss:0.5680  g_loss:1.6962
# epoch:891  d_loss:0.3596  g_loss:2.2366
# epoch:892  d_loss:0.5794  g_loss:2.6208
# epoch:893  d_loss:0.4042  g_loss:2.8396
# epoch:894  d_loss:0.3910  g_loss:2.4029
# epoch:895  d_loss:0.4195  g_loss:2.2555
# epoch:896  d_loss:0.3254  g_loss:1.6520
# epoch:897  d_loss:0.4310  g_loss:1.3843
# epoch:898  d_loss:0.3812  g_loss:1.6255
# epoch:899  d_loss:0.1942  g_loss:2.3695
# epoch:900  d_loss:0.2158  g_loss:3.0361
# epoch:901  d_loss:0.2460  g_loss:3.1675
# epoch:902  d_loss:0.2780  g_loss:2.7018
# epoch:903  d_loss:0.2813  g_loss:2.6321
# epoch:904  d_loss:0.3900  g_loss:2.4664
# epoch:905  d_loss:0.2465  g_loss:2.1288
# epoch:906  d_loss:0.4017  g_loss:2.3165
# epoch:907  d_loss:0.2672  g_loss:2.3150
# epoch:908  d_loss:0.3082  g_loss:2.6520
# epoch:909  d_loss:0.2213  g_loss:2.5371
# epoch:910  d_loss:0.2541  g_loss:3.3774
# epoch:911  d_loss:0.2478  g_loss:3.3073
# epoch:912  d_loss:0.1889  g_loss:2.7381
# epoch:913  d_loss:0.3379  g_loss:2.4250
# epoch:914  d_loss:0.3755  g_loss:2.0294
# epoch:915  d_loss:0.1868  g_loss:2.1886
# epoch:916  d_loss:0.2005  g_loss:1.8801
# epoch:917  d_loss:0.2031  g_loss:3.1030
# epoch:918  d_loss:0.2487  g_loss:2.7121
# epoch:919  d_loss:0.3553  g_loss:3.3316
# epoch:920  d_loss:0.2131  g_loss:2.8655
# epoch:921  d_loss:0.2350  g_loss:2.3664
# epoch:922  d_loss:0.2148  g_loss:2.3352
# epoch:923  d_loss:0.3210  g_loss:1.8459
# epoch:924  d_loss:0.2730  g_loss:1.8948
# epoch:925  d_loss:0.1890  g_loss:2.2006
# epoch:926  d_loss:0.1548  g_loss:2.6392
# epoch:927  d_loss:0.1218  g_loss:3.1226
# epoch:928  d_loss:0.2357  g_loss:2.6301
# epoch:929  d_loss:0.3658  g_loss:2.3440
# epoch:930  d_loss:0.2101  g_loss:2.9786
# epoch:931  d_loss:0.4758  g_loss:2.1813
# epoch:932  d_loss:0.2621  g_loss:2.5851
# epoch:933  d_loss:0.3000  g_loss:2.2042
# epoch:934  d_loss:0.3613  g_loss:2.8231
# epoch:935  d_loss:0.2226  g_loss:2.9339
# epoch:936  d_loss:0.5708  g_loss:2.5932
# epoch:937  d_loss:0.3827  g_loss:2.1557
# epoch:938  d_loss:0.4036  g_loss:2.5456
# epoch:939  d_loss:0.3204  g_loss:3.0080
# epoch:940  d_loss:0.4502  g_loss:2.8045
# epoch:941  d_loss:0.6052  g_loss:2.1338
# epoch:942  d_loss:0.4639  g_loss:1.9959
# epoch:943  d_loss:0.4175  g_loss:1.4954
# epoch:944  d_loss:0.6038  g_loss:1.7221
# epoch:945  d_loss:0.6629  g_loss:1.8853
# epoch:946  d_loss:0.6924  g_loss:1.7187
# epoch:947  d_loss:0.6545  g_loss:1.5357
# epoch:948  d_loss:0.6520  g_loss:1.5924
# epoch:949  d_loss:0.6313  g_loss:1.6806
# epoch:950  d_loss:0.4548  g_loss:1.9396
# epoch:951  d_loss:0.4109  g_loss:1.8089
# epoch:952  d_loss:0.3971  g_loss:2.0588
# epoch:953  d_loss:0.3892  g_loss:1.8337
# epoch:954  d_loss:0.4287  g_loss:2.0896
# epoch:955  d_loss:0.2115  g_loss:2.1114
# epoch:956  d_loss:0.2816  g_loss:2.0582
# epoch:957  d_loss:0.2488  g_loss:2.1877
# epoch:958  d_loss:0.3406  g_loss:1.9513
# epoch:959  d_loss:0.2173  g_loss:2.1000
# epoch:960  d_loss:0.2213  g_loss:2.4704
# epoch:961  d_loss:0.3089  g_loss:2.4512
# epoch:962  d_loss:0.2281  g_loss:2.2255
# epoch:963  d_loss:0.2544  g_loss:2.5347
# epoch:964  d_loss:0.2864  g_loss:2.5482
# epoch:965  d_loss:0.2454  g_loss:2.7668
# epoch:966  d_loss:0.3958  g_loss:2.3486
# epoch:967  d_loss:0.3874  g_loss:2.1431
# epoch:968  d_loss:0.2338  g_loss:2.2338
# epoch:969  d_loss:0.3475  g_loss:2.0977
# epoch:970  d_loss:0.3573  g_loss:2.0250
# epoch:971  d_loss:0.4175  g_loss:1.9091
# epoch:972  d_loss:0.3475  g_loss:2.3180
# epoch:973  d_loss:0.4511  g_loss:2.2806
# epoch:974  d_loss:0.6199  g_loss:1.5532
# epoch:975  d_loss:0.5785  g_loss:1.6754
# epoch:976  d_loss:0.5593  g_loss:1.1769
# epoch:977  d_loss:0.4343  g_loss:1.6919
# epoch:978  d_loss:0.4882  g_loss:2.1475
# epoch:979  d_loss:0.5429  g_loss:2.0161
# epoch:980  d_loss:0.6288  g_loss:1.8482
# epoch:981  d_loss:0.6359  g_loss:1.0872
# epoch:982  d_loss:0.5011  g_loss:1.1047
# epoch:983  d_loss:0.6824  g_loss:0.9432
# epoch:984  d_loss:0.4405  g_loss:1.2313
# epoch:985  d_loss:0.5624  g_loss:1.6136
# epoch:986  d_loss:0.6908  g_loss:1.6999
# epoch:987  d_loss:0.4683  g_loss:1.4316
# epoch:988  d_loss:0.4763  g_loss:1.5908
# epoch:989  d_loss:0.6008  g_loss:1.2872
# epoch:990  d_loss:0.4085  g_loss:1.3571
# epoch:991  d_loss:0.3473  g_loss:1.3960
# epoch:992  d_loss:0.3348  g_loss:1.7500
# epoch:993  d_loss:0.3622  g_loss:1.7350
# epoch:994  d_loss:0.3707  g_loss:2.0706
# epoch:995  d_loss:0.4338  g_loss:1.6843
# epoch:996  d_loss:0.4435  g_loss:1.6378
# epoch:997  d_loss:0.3971  g_loss:1.7979
# epoch:998  d_loss:0.2329  g_loss:2.0250
# epoch:999  d_loss:0.2850  g_loss:2.2826
# epoch:1000  d_loss:0.2717  g_loss:2.1619
# epoch:1001  d_loss:0.4145  g_loss:2.3286
# epoch:1002  d_loss:0.3652  g_loss:2.3624
# epoch:1003  d_loss:0.3963  g_loss:1.6941
# epoch:1004  d_loss:0.3952  g_loss:1.5236
# epoch:1005  d_loss:0.3746  g_loss:1.4315
# epoch:1006  d_loss:0.4168  g_loss:1.8912
# epoch:1007  d_loss:0.3961  g_loss:2.0039
# epoch:1008  d_loss:0.5391  g_loss:1.7606
# epoch:1009  d_loss:0.4891  g_loss:2.3423
# epoch:1010  d_loss:0.4755  g_loss:2.3887
# epoch:1011  d_loss:0.4084  g_loss:1.8382
# epoch:1012  d_loss:0.5019  g_loss:1.4962
# epoch:1013  d_loss:0.4506  g_loss:1.5742
# epoch:1014  d_loss:0.5649  g_loss:1.6378
# epoch:1015  d_loss:0.3576  g_loss:1.9568
# epoch:1016  d_loss:0.5678  g_loss:2.4154
# epoch:1017  d_loss:0.5068  g_loss:2.3375
# epoch:1018  d_loss:0.2776  g_loss:2.3707
# epoch:1019  d_loss:0.5022  g_loss:1.5735
# epoch:1020  d_loss:0.3887  g_loss:1.9773
# epoch:1021  d_loss:0.3477  g_loss:1.9429
# epoch:1022  d_loss:0.3365  g_loss:2.2960
# epoch:1023  d_loss:0.3258  g_loss:2.9409
# epoch:1024  d_loss:0.3462  g_loss:2.9722
# epoch:1025  d_loss:0.2259  g_loss:3.0509
# epoch:1026  d_loss:0.4428  g_loss:2.1622
# epoch:1027  d_loss:0.3141  g_loss:1.9346
# epoch:1028  d_loss:0.3402  g_loss:2.6652
# epoch:1029  d_loss:0.3980  g_loss:2.5006
# epoch:1030  d_loss:0.2799  g_loss:3.4163
# epoch:1031  d_loss:0.2770  g_loss:3.4784
# epoch:1032  d_loss:0.2517  g_loss:2.9386
# epoch:1033  d_loss:0.3829  g_loss:2.1823
# epoch:1034  d_loss:0.3500  g_loss:1.7823
# epoch:1035  d_loss:0.3015  g_loss:2.3521
# epoch:1036  d_loss:0.3525  g_loss:2.4120
# epoch:1037  d_loss:0.3810  g_loss:2.9619
# epoch:1038  d_loss:0.3192  g_loss:2.8765
# epoch:1039  d_loss:0.3421  g_loss:2.1802
# epoch:1040  d_loss:0.3936  g_loss:2.1118
# epoch:1041  d_loss:0.4033  g_loss:1.9556
# epoch:1042  d_loss:0.5084  g_loss:2.1988
# epoch:1043  d_loss:0.4420  g_loss:2.4935
# epoch:1044  d_loss:0.3543  g_loss:2.3679
# epoch:1045  d_loss:0.4639  g_loss:2.0007
# epoch:1046  d_loss:0.4889  g_loss:2.0897
# epoch:1047  d_loss:0.3820  g_loss:1.8756
# epoch:1048  d_loss:0.3295  g_loss:2.4180
# epoch:1049  d_loss:0.2509  g_loss:2.6332
# epoch:1050  d_loss:0.2791  g_loss:3.2669
# epoch:1051  d_loss:0.4494  g_loss:2.8753
# epoch:1052  d_loss:0.4614  g_loss:1.9598
# epoch:1053  d_loss:0.3783  g_loss:1.9458
# epoch:1054  d_loss:0.3134  g_loss:2.3373
# epoch:1055  d_loss:0.3283  g_loss:2.7228
# epoch:1056  d_loss:0.3386  g_loss:2.6331
# epoch:1057  d_loss:0.2355  g_loss:2.7505
# epoch:1058  d_loss:0.3587  g_loss:2.2949
# epoch:1059  d_loss:0.3389  g_loss:2.1455
# epoch:1060  d_loss:0.3902  g_loss:2.3202
# epoch:1061  d_loss:0.4347  g_loss:2.6040
# epoch:1062  d_loss:0.2591  g_loss:2.6047
# epoch:1063  d_loss:0.3444  g_loss:2.6523
# epoch:1064  d_loss:0.2486  g_loss:2.2717
# epoch:1065  d_loss:0.4462  g_loss:2.4370
# epoch:1066  d_loss:0.4387  g_loss:1.8607
# epoch:1067  d_loss:0.2525  g_loss:2.3456
# epoch:1068  d_loss:0.5242  g_loss:2.4430
# epoch:1069  d_loss:0.4432  g_loss:2.1498
# epoch:1070  d_loss:0.4714  g_loss:2.0942
# epoch:1071  d_loss:0.3051  g_loss:2.1354
# epoch:1072  d_loss:0.2320  g_loss:2.3422
# epoch:1073  d_loss:0.3603  g_loss:2.2423
# epoch:1074  d_loss:0.3006  g_loss:1.9811
# epoch:1075  d_loss:0.2924  g_loss:2.1455
# epoch:1076  d_loss:0.3603  g_loss:2.3272
# epoch:1077  d_loss:0.3221  g_loss:2.4283
# epoch:1078  d_loss:0.2352  g_loss:2.8650
# epoch:1079  d_loss:0.3649  g_loss:2.9690
# epoch:1080  d_loss:0.3115  g_loss:2.9292
# epoch:1081  d_loss:0.4386  g_loss:2.4240
# epoch:1082  d_loss:0.3735  g_loss:1.8944
# epoch:1083  d_loss:0.2678  g_loss:2.4618
# epoch:1084  d_loss:0.3541  g_loss:2.5156
# epoch:1085  d_loss:0.4162  g_loss:2.4016
# epoch:1086  d_loss:0.4530  g_loss:2.9586
# epoch:1087  d_loss:0.2798  g_loss:3.0214
# epoch:1088  d_loss:0.4816  g_loss:2.9587
# epoch:1089  d_loss:0.3945  g_loss:2.0746
# epoch:1090  d_loss:0.3563  g_loss:2.0241
# epoch:1091  d_loss:0.2895  g_loss:2.4269
# epoch:1092  d_loss:0.3792  g_loss:2.1226
# epoch:1093  d_loss:0.3728  g_loss:2.4235
# epoch:1094  d_loss:0.2845  g_loss:3.0643
# epoch:1095  d_loss:0.4308  g_loss:2.4435
# epoch:1096  d_loss:0.4520  g_loss:2.7876
# epoch:1097  d_loss:0.3633  g_loss:2.3315
# epoch:1098  d_loss:0.3335  g_loss:2.4966
# epoch:1099  d_loss:0.4717  g_loss:2.6785
# epoch:1100  d_loss:0.4516  g_loss:2.2979
# epoch:1101  d_loss:0.4741  g_loss:2.4368
# epoch:1102  d_loss:0.5349  g_loss:2.2097
# epoch:1103  d_loss:0.3376  g_loss:2.4560
# epoch:1104  d_loss:0.4245  g_loss:2.4868
# epoch:1105  d_loss:0.4191  g_loss:1.8492
# epoch:1106  d_loss:0.3622  g_loss:2.1352
# epoch:1107  d_loss:0.3903  g_loss:2.6215
# epoch:1108  d_loss:0.4771  g_loss:2.2726
# epoch:1109  d_loss:0.5025  g_loss:2.5325
# epoch:1110  d_loss:0.2523  g_loss:2.1649
# epoch:1111  d_loss:0.3179  g_loss:2.8452
# epoch:1112  d_loss:0.4227  g_loss:2.6342
# epoch:1113  d_loss:0.4265  g_loss:2.1002
# epoch:1114  d_loss:0.3516  g_loss:2.2025
# epoch:1115  d_loss:0.3515  g_loss:2.3875
# epoch:1116  d_loss:0.2996  g_loss:2.3420
# epoch:1117  d_loss:0.3172  g_loss:2.2230
# epoch:1118  d_loss:0.3079  g_loss:2.7068
# epoch:1119  d_loss:0.4165  g_loss:1.8245
# epoch:1120  d_loss:0.3056  g_loss:2.3161
# epoch:1121  d_loss:0.1831  g_loss:2.8289
# epoch:1122  d_loss:0.2497  g_loss:2.9423
# epoch:1123  d_loss:0.2380  g_loss:3.1050
# epoch:1124  d_loss:0.3010  g_loss:2.2994
# epoch:1125  d_loss:0.2581  g_loss:2.5154
# epoch:1126  d_loss:0.2868  g_loss:2.2404
# epoch:1127  d_loss:0.1594  g_loss:3.0329
# epoch:1128  d_loss:0.3013  g_loss:2.6516
# epoch:1129  d_loss:0.3009  g_loss:2.8760
# epoch:1130  d_loss:0.3420  g_loss:2.8523
# epoch:1131  d_loss:0.3773  g_loss:2.5785
# epoch:1132  d_loss:0.2791  g_loss:2.3993
# epoch:1133  d_loss:0.2327  g_loss:2.3539
# epoch:1134  d_loss:0.3501  g_loss:2.7724
# epoch:1135  d_loss:0.2324  g_loss:2.7893
# epoch:1136  d_loss:0.3555  g_loss:2.5366
# epoch:1137  d_loss:0.3377  g_loss:2.4485
# epoch:1138  d_loss:0.3449  g_loss:2.6818
# epoch:1139  d_loss:0.3416  g_loss:2.3494
# epoch:1140  d_loss:0.3949  g_loss:2.0016
# epoch:1141  d_loss:0.4796  g_loss:1.8750
# epoch:1142  d_loss:0.4717  g_loss:1.9814
# epoch:1143  d_loss:0.4030  g_loss:1.6307
# epoch:1144  d_loss:0.4447  g_loss:1.7942
# epoch:1145  d_loss:0.4772  g_loss:1.9472
# epoch:1146  d_loss:0.3279  g_loss:2.3680
# epoch:1147  d_loss:0.3292  g_loss:2.6246
# epoch:1148  d_loss:0.4654  g_loss:2.2134
# epoch:1149  d_loss:0.3710  g_loss:1.6292
# epoch:1150  d_loss:0.5407  g_loss:1.8078
# epoch:1151  d_loss:0.4729  g_loss:2.4202
# epoch:1152  d_loss:0.4129  g_loss:2.7353
# epoch:1153  d_loss:0.4359  g_loss:2.1616
# epoch:1154  d_loss:0.4171  g_loss:2.2346
# epoch:1155  d_loss:0.3866  g_loss:2.4858
# epoch:1156  d_loss:0.2924  g_loss:2.1632
# epoch:1157  d_loss:0.4351  g_loss:2.0664
# epoch:1158  d_loss:0.1949  g_loss:2.4862
# epoch:1159  d_loss:0.2574  g_loss:2.6894
# epoch:1160  d_loss:0.2378  g_loss:3.0891
# epoch:1161  d_loss:0.4833  g_loss:2.1475
# epoch:1162  d_loss:0.4105  g_loss:2.0947
# epoch:1163  d_loss:0.3840  g_loss:1.9723
# epoch:1164  d_loss:0.2084  g_loss:2.3203
# epoch:1165  d_loss:0.2958  g_loss:2.4980
# epoch:1166  d_loss:0.2793  g_loss:2.0697
# epoch:1167  d_loss:0.3961  g_loss:2.7036
# epoch:1168  d_loss:0.2642  g_loss:2.9519
# epoch:1169  d_loss:0.2128  g_loss:2.4750
# epoch:1170  d_loss:0.2954  g_loss:2.3429
# epoch:1171  d_loss:0.3223  g_loss:2.8880
# epoch:1172  d_loss:0.2551  g_loss:2.9990
# epoch:1173  d_loss:0.4144  g_loss:3.1743
# epoch:1174  d_loss:0.5010  g_loss:1.7818
# epoch:1175  d_loss:0.3382  g_loss:2.2826
# epoch:1176  d_loss:0.4189  g_loss:2.2054
# epoch:1177  d_loss:0.2634  g_loss:2.7227
# epoch:1178  d_loss:0.2360  g_loss:2.8496
# epoch:1179  d_loss:0.4543  g_loss:2.6342
# epoch:1180  d_loss:0.3395  g_loss:3.2816
# epoch:1181  d_loss:0.3542  g_loss:2.5716
# epoch:1182  d_loss:0.3751  g_loss:1.7724
# epoch:1183  d_loss:0.2579  g_loss:2.3302
# epoch:1184  d_loss:0.2138  g_loss:2.3721
# epoch:1185  d_loss:0.2937  g_loss:2.3402
# epoch:1186  d_loss:0.3910  g_loss:2.0846
# epoch:1187  d_loss:0.3668  g_loss:2.0252
# epoch:1188  d_loss:0.2499  g_loss:1.8728
# epoch:1189  d_loss:0.3432  g_loss:2.4415
# epoch:1190  d_loss:0.3444  g_loss:2.4635
# epoch:1191  d_loss:0.4281  g_loss:1.7817
# epoch:1192  d_loss:0.3038  g_loss:2.4927
# epoch:1193  d_loss:0.3860  g_loss:1.8288
# epoch:1194  d_loss:0.5906  g_loss:1.6814
# epoch:1195  d_loss:0.5666  g_loss:1.7384
# epoch:1196  d_loss:0.5482  g_loss:1.9235
# ...
# epoch:3619  d_loss:0.5919  g_loss:1.4201
# epoch:3620  d_loss:0.4524  g_loss:1.5694
# epoch:3621  d_loss:0.6519  g_loss:1.7195
# epoch:3622  d_loss:0.5076  g_loss:1.7904
# epoch:3623  d_loss:0.5783  g_loss:1.5209
# epoch:3624  d_loss:0.4726  g_loss:1.4380
# epoch:3625  d_loss:0.4727  g_loss:1.4498
# epoch:3626  d_loss:0.4668  g_loss:1.3721
# epoch:3627  d_loss:0.3954  g_loss:1.6102
# epoch:3628  d_loss:0.5402  g_loss:1.5635
# epoch:3629  d_loss:0.5352  g_loss:1.8020
# epoch:3630  d_loss:0.5850  g_loss:1.6986
# epoch:3631  d_loss:0.4654  g_loss:1.8262
# epoch:3632  d_loss:0.4366  g_loss:1.9171
# epoch:3633  d_loss:0.5249  g_loss:2.0358
# epoch:3634  d_loss:0.4078  g_loss:1.6811
# epoch:3635  d_loss:0.4401  g_loss:1.2167
# epoch:3636  d_loss:0.6061  g_loss:1.4116
# epoch:3637  d_loss:0.4661  g_loss:1.4800
# epoch:3638  d_loss:0.5335  g_loss:1.4473
# epoch:3639  d_loss:0.4778  g_loss:1.6988
# epoch:3640  d_loss:0.5813  g_loss:1.7340
# epoch:3641  d_loss:0.4693  g_loss:1.6424
# epoch:3642  d_loss:0.6717  g_loss:1.9281
# epoch:3643  d_loss:0.5303  g_loss:1.7129
# epoch:3644  d_loss:0.5468  g_loss:1.5144
# epoch:3645  d_loss:0.6920  g_loss:1.1164
# epoch:3646  d_loss:0.5684  g_loss:1.0970
# epoch:3647  d_loss:0.5464  g_loss:1.4123
# epoch:3648  d_loss:0.6937  g_loss:1.7737
# epoch:3649  d_loss:0.6011  g_loss:1.5663
# epoch:3650  d_loss:0.7016  g_loss:1.7520
# epoch:3651  d_loss:0.4697  g_loss:1.5059
# epoch:3652  d_loss:0.5322  g_loss:1.5273
# epoch:3653  d_loss:0.6022  g_loss:1.4746
# epoch:3654  d_loss:0.5307  g_loss:1.1744
# epoch:3655  d_loss:0.4894  g_loss:1.2748
# epoch:3656  d_loss:0.4861  g_loss:1.4001
# epoch:3657  d_loss:0.5709  g_loss:1.4756
# epoch:3658  d_loss:0.5775  g_loss:1.6304
# epoch:3659  d_loss:0.5086  g_loss:1.6317
# epoch:3660  d_loss:0.4656  g_loss:1.6822
# epoch:3661  d_loss:0.3183  g_loss:1.6677
# epoch:3662  d_loss:0.5093  g_loss:1.2678
# epoch:3663  d_loss:0.4377  g_loss:1.2926
# epoch:3664  d_loss:0.4647  g_loss:1.5289
# epoch:3665  d_loss:0.4333  g_loss:1.3469
# epoch:3666  d_loss:0.4290  g_loss:1.6294
# epoch:3667  d_loss:0.3984  g_loss:1.6877
# epoch:3668  d_loss:0.5383  g_loss:1.6198
# epoch:3669  d_loss:0.6198  g_loss:1.4715
# epoch:3670  d_loss:0.5527  g_loss:1.5658
# epoch:3671  d_loss:0.4941  g_loss:1.1448
# epoch:3672  d_loss:0.5578  g_loss:1.2931
# epoch:3673  d_loss:0.4880  g_loss:1.5587
# epoch:3674  d_loss:0.6580  g_loss:1.6177
# epoch:3675  d_loss:0.3472  g_loss:1.7546
# epoch:3676  d_loss:0.4809  g_loss:1.5657
# epoch:3677  d_loss:0.5381  g_loss:1.6406
# epoch:3678  d_loss:0.5930  g_loss:1.0846
# epoch:3679  d_loss:0.6009  g_loss:1.3100
# epoch:3680  d_loss:0.6426  g_loss:1.3782
# epoch:3681  d_loss:0.5733  g_loss:1.3190
# epoch:3682  d_loss:0.5497  g_loss:1.5207
# epoch:3683  d_loss:0.5489  g_loss:1.2758
# epoch:3684  d_loss:0.5587  g_loss:1.5256
# epoch:3685  d_loss:0.4392  g_loss:1.6307
# epoch:3686  d_loss:0.4292  g_loss:1.6992
# epoch:3687  d_loss:0.5007  g_loss:1.7008
# epoch:3688  d_loss:0.5362  g_loss:1.4186
# epoch:3689  d_loss:0.4538  g_loss:1.3054
# epoch:3690  d_loss:0.6791  g_loss:1.1450
# epoch:3691  d_loss:0.4941  g_loss:1.3112
# epoch:3692  d_loss:0.4351  g_loss:1.6643
# epoch:3693  d_loss:0.5083  g_loss:1.6454
# epoch:3694  d_loss:0.5143  g_loss:1.5782
# epoch:3695  d_loss:0.4469  g_loss:1.4693
# epoch:3696  d_loss:0.4630  g_loss:1.1998
# epoch:3697  d_loss:0.5560  g_loss:1.2317
# epoch:3698  d_loss:0.5237  g_loss:1.5042
# epoch:3699  d_loss:0.4664  g_loss:1.3937
# epoch:3700  d_loss:0.5805  g_loss:1.5310
# epoch:3701  d_loss:0.4826  g_loss:1.5617
# epoch:3702  d_loss:0.4729  g_loss:1.5612
# epoch:3703  d_loss:0.4616  g_loss:1.6980
# epoch:3704  d_loss:0.5555  g_loss:1.5669
# epoch:3705  d_loss:0.5219  g_loss:1.5436
# epoch:3706  d_loss:0.4555  g_loss:1.5670
# epoch:3707  d_loss:0.5085  g_loss:1.3802
# epoch:3708  d_loss:0.5645  g_loss:1.4971
# epoch:3709  d_loss:0.3661  g_loss:1.4534
# epoch:3710  d_loss:0.4505  g_loss:1.5662
# epoch:3711  d_loss:0.5073  g_loss:1.3691
# epoch:3712  d_loss:0.5634  g_loss:1.7107
# epoch:3713  d_loss:0.5118  g_loss:1.6130
# epoch:3714  d_loss:0.4619  g_loss:1.5941
# epoch:3715  d_loss:0.6274  g_loss:1.4153
# epoch:3716  d_loss:0.5679  g_loss:1.4859
# epoch:3717  d_loss:0.4687  g_loss:1.5362
# epoch:3718  d_loss:0.5757  g_loss:1.6636
# epoch:3719  d_loss:0.5134  g_loss:1.4292
# epoch:3720  d_loss:0.4540  g_loss:1.8104
# epoch:3721  d_loss:0.3923  g_loss:1.4062
# epoch:3722  d_loss:0.5094  g_loss:1.3544
# epoch:3723  d_loss:0.4503  g_loss:1.4657
# epoch:3724  d_loss:0.4409  g_loss:1.8633
# epoch:3725  d_loss:0.4958  g_loss:1.7150
# epoch:3726  d_loss:0.5583  g_loss:1.1827
# epoch:3727  d_loss:0.4474  g_loss:1.4961
# epoch:3728  d_loss:0.5461  g_loss:1.2843
# epoch:3729  d_loss:0.4740  g_loss:1.8408
# epoch:3730  d_loss:0.5531  g_loss:1.5435
# epoch:3731  d_loss:0.5537  g_loss:1.4117
# epoch:3732  d_loss:0.4808  g_loss:1.4903
# epoch:3733  d_loss:0.5307  g_loss:1.3753
# epoch:3734  d_loss:0.5562  g_loss:1.3953
# epoch:3735  d_loss:0.4139  g_loss:1.4996
# epoch:3736  d_loss:0.5863  g_loss:1.2844
# epoch:3737  d_loss:0.3956  g_loss:1.4718
# epoch:3738  d_loss:0.4879  g_loss:1.3538
# epoch:3739  d_loss:0.5290  g_loss:1.4877
# epoch:3740  d_loss:0.4682  g_loss:1.4339
# epoch:3741  d_loss:0.5260  g_loss:1.2796
# epoch:3742  d_loss:0.4418  g_loss:1.6274
# epoch:3743  d_loss:0.5449  g_loss:1.7581
# epoch:3744  d_loss:0.4179  g_loss:2.0058
# epoch:3745  d_loss:0.5663  g_loss:1.6085
# epoch:3746  d_loss:0.3687  g_loss:2.0187
# epoch:3747  d_loss:0.5908  g_loss:1.5627
# epoch:3748  d_loss:0.4234  g_loss:1.9172
# epoch:3749  d_loss:0.4960  g_loss:1.6643
# epoch:3750  d_loss:0.4502  g_loss:1.7217
# epoch:3751  d_loss:0.4270  g_loss:1.8075
# epoch:3752  d_loss:0.4023  g_loss:1.5350
# epoch:3753  d_loss:0.6124  g_loss:1.8615
# epoch:3754  d_loss:0.4868  g_loss:1.9007
# epoch:3755  d_loss:0.5590  g_loss:1.6109
# epoch:3756  d_loss:0.4022  g_loss:1.5697
# epoch:3757  d_loss:0.3594  g_loss:2.0765
# epoch:3758  d_loss:0.5967  g_loss:1.6003
# epoch:3759  d_loss:0.4275  g_loss:1.7826
# epoch:3760  d_loss:0.4720  g_loss:1.7896
# epoch:3761  d_loss:0.4949  g_loss:1.0624
# epoch:3762  d_loss:0.5779  g_loss:1.6329
# epoch:3763  d_loss:0.4304  g_loss:1.7846
# epoch:3764  d_loss:0.4877  g_loss:2.0317
# epoch:3765  d_loss:0.5414  g_loss:2.0861
# epoch:3766  d_loss:0.3741  g_loss:2.1796
# epoch:3767  d_loss:0.5078  g_loss:1.8907
# epoch:3768  d_loss:0.6458  g_loss:1.6293
# epoch:3769  d_loss:0.4374  g_loss:1.7261
# epoch:3770  d_loss:0.5160  g_loss:1.4986
# epoch:3771  d_loss:0.5476  g_loss:1.3975
# epoch:3772  d_loss:0.6571  g_loss:1.3752
# epoch:3773  d_loss:0.5872  g_loss:1.4298
# epoch:3774  d_loss:0.4864  g_loss:1.9859
# epoch:3775  d_loss:0.5131  g_loss:1.9305
# epoch:3776  d_loss:0.5419  g_loss:1.9851
# epoch:3777  d_loss:0.4427  g_loss:1.6957
# epoch:3778  d_loss:0.5628  g_loss:1.6168
# epoch:3779  d_loss:0.5329  g_loss:1.6566
# epoch:3780  d_loss:0.4321  g_loss:1.4456
# epoch:3781  d_loss:0.4992  g_loss:1.8153
# epoch:3782  d_loss:0.6120  g_loss:1.7757
# epoch:3783  d_loss:0.4257  g_loss:2.0753
# epoch:3784  d_loss:0.6231  g_loss:2.0052
# epoch:3785  d_loss:0.5062  g_loss:1.4465
# epoch:3786  d_loss:0.4256  g_loss:1.6483
# epoch:3787  d_loss:0.5385  g_loss:1.5116
# epoch:3788  d_loss:0.4429  g_loss:1.7527
# epoch:3789  d_loss:0.4064  g_loss:1.6956
# epoch:3790  d_loss:0.5493  g_loss:1.4802
# epoch:3791  d_loss:0.3886  g_loss:1.9733
# epoch:3792  d_loss:0.5807  g_loss:1.8146
# epoch:3793  d_loss:0.4494  g_loss:1.6693
# epoch:3794  d_loss:0.4331  g_loss:1.6789
# epoch:3795  d_loss:0.4300  g_loss:1.9670
# epoch:3796  d_loss:0.4477  g_loss:1.9868
# epoch:3797  d_loss:0.4803  g_loss:1.8530
# epoch:3798  d_loss:0.4778  g_loss:1.4699
# epoch:3799  d_loss:0.4866  g_loss:1.4428
# epoch:3800  d_loss:0.4858  g_loss:1.4895
# epoch:3801  d_loss:0.3419  g_loss:2.3039
# epoch:3802  d_loss:0.4433  g_loss:2.1506
# epoch:3803  d_loss:0.4940  g_loss:1.6968
# epoch:3804  d_loss:0.5008  g_loss:1.4039
# epoch:3805  d_loss:0.5215  g_loss:1.7081
# epoch:3806  d_loss:0.4022  g_loss:1.5639
# epoch:3807  d_loss:0.5509  g_loss:1.9242
# epoch:3808  d_loss:0.4715  g_loss:2.1109
# epoch:3809  d_loss:0.5992  g_loss:2.2871
# epoch:3810  d_loss:0.5610  g_loss:1.4285
# epoch:3811  d_loss:0.5792  g_loss:1.7377
# epoch:3812  d_loss:0.5533  g_loss:1.6463
# epoch:3813  d_loss:0.4711  g_loss:2.0262
# epoch:3814  d_loss:0.5100  g_loss:1.9778
# epoch:3815  d_loss:0.4969  g_loss:1.5334
# epoch:3816  d_loss:0.4770  g_loss:1.6850
# epoch:3817  d_loss:0.5033  g_loss:1.4465
# epoch:3818  d_loss:0.4968  g_loss:1.7981
# epoch:3819  d_loss:0.4734  g_loss:2.0809
# epoch:3820  d_loss:0.4871  g_loss:1.7018
# epoch:3821  d_loss:0.8316  g_loss:1.4230
# epoch:3822  d_loss:0.5661  g_loss:1.7679
# epoch:3823  d_loss:0.4749  g_loss:2.0341
# epoch:3824  d_loss:0.3813  g_loss:2.2518
# epoch:3825  d_loss:0.5419  g_loss:2.0450
# epoch:3826  d_loss:0.5635  g_loss:1.5498
# epoch:3827  d_loss:0.4997  g_loss:1.8844
# epoch:3828  d_loss:0.6093  g_loss:1.6429
# epoch:3829  d_loss:0.3945  g_loss:1.8124
# epoch:3830  d_loss:0.4447  g_loss:2.1433
# epoch:3831  d_loss:0.4556  g_loss:1.6897
# epoch:3832  d_loss:0.4148  g_loss:1.8436
# epoch:3833  d_loss:0.4320  g_loss:1.7479
# epoch:3834  d_loss:0.5539  g_loss:1.6743
# epoch:3835  d_loss:0.6035  g_loss:1.4441
# epoch:3836  d_loss:0.4358  g_loss:2.1239
# epoch:3837  d_loss:0.4384  g_loss:2.0405
# epoch:3838  d_loss:0.6174  g_loss:1.7512
# epoch:3839  d_loss:0.5994  g_loss:1.6921
# epoch:3840  d_loss:0.4659  g_loss:1.1862
# epoch:3841  d_loss:0.4983  g_loss:1.6460
# epoch:3842  d_loss:0.5854  g_loss:1.3802
# epoch:3843  d_loss:0.3670  g_loss:1.8812
# epoch:3844  d_loss:0.5526  g_loss:1.7722
# epoch:3845  d_loss:0.3813  g_loss:1.5382
# epoch:3846  d_loss:0.4816  g_loss:1.5991
# epoch:3847  d_loss:0.5329  g_loss:1.4924
# epoch:3848  d_loss:0.4761  g_loss:1.7785
# epoch:3849  d_loss:0.4591  g_loss:1.9377
# epoch:3850  d_loss:0.4401  g_loss:1.8340
# epoch:3851  d_loss:0.4542  g_loss:2.0647
# epoch:3852  d_loss:0.4278  g_loss:2.0766
# epoch:3853  d_loss:0.4573  g_loss:1.4399
# epoch:3854  d_loss:0.6092  g_loss:1.3198
# epoch:3855  d_loss:0.5925  g_loss:1.5310
# epoch:3856  d_loss:0.3870  g_loss:1.8552
# epoch:3857  d_loss:0.3489  g_loss:1.5524
# epoch:3858  d_loss:0.3129  g_loss:2.1182
# epoch:3859  d_loss:0.3481  g_loss:1.8261
# epoch:3860  d_loss:0.4001  g_loss:1.7448
# epoch:3861  d_loss:0.3998  g_loss:2.0390
# epoch:3862  d_loss:0.4829  g_loss:2.1965
# epoch:3863  d_loss:0.4660  g_loss:1.9761
# epoch:3864  d_loss:0.3665  g_loss:1.7816
# epoch:3865  d_loss:0.5673  g_loss:1.5277
# epoch:3866  d_loss:0.5405  g_loss:1.5521
# epoch:3867  d_loss:0.4871  g_loss:1.7325
# epoch:3868  d_loss:0.5441  g_loss:1.9284
# epoch:3869  d_loss:0.5629  g_loss:1.3466
# epoch:3870  d_loss:0.6166  g_loss:1.4474
# epoch:3871  d_loss:0.5317  g_loss:1.6412
# epoch:3872  d_loss:0.5899  g_loss:1.2682
# epoch:3873  d_loss:0.6527  g_loss:1.1668
# epoch:3874  d_loss:0.6434  g_loss:1.2158
# epoch:3875  d_loss:0.5324  g_loss:1.4695
# epoch:3876  d_loss:0.6551  g_loss:1.4442
# epoch:3877  d_loss:0.5915  g_loss:1.5559
# epoch:3878  d_loss:0.5121  g_loss:1.6829
# epoch:3879  d_loss:0.5314  g_loss:1.4283
# epoch:3880  d_loss:0.4608  g_loss:1.5558
# epoch:3881  d_loss:0.5399  g_loss:1.6365
# epoch:3882  d_loss:0.5107  g_loss:1.9269
# epoch:3883  d_loss:0.5118  g_loss:1.8308
# epoch:3884  d_loss:0.4876  g_loss:1.9820
# epoch:3885  d_loss:0.4134  g_loss:1.9594
# epoch:3886  d_loss:0.4560  g_loss:1.9264
# epoch:3887  d_loss:0.4356  g_loss:1.8927
# epoch:3888  d_loss:0.4541  g_loss:2.0341
# epoch:3889  d_loss:0.3884  g_loss:1.9373
# epoch:3890  d_loss:0.3629  g_loss:1.7743
# epoch:3891  d_loss:0.5698  g_loss:2.0724
# epoch:3892  d_loss:0.5620  g_loss:1.9438
# epoch:3893  d_loss:0.5106  g_loss:2.2343
# epoch:3894  d_loss:0.4683  g_loss:2.1132
# epoch:3895  d_loss:0.5009  g_loss:2.2842
# epoch:3896  d_loss:0.4782  g_loss:2.3929
# epoch:3897  d_loss:0.6260  g_loss:1.7501
# epoch:3898  d_loss:0.4579  g_loss:1.8158
# epoch:3899  d_loss:0.4883  g_loss:1.4708
# epoch:3900  d_loss:0.6275  g_loss:1.5332
# epoch:3901  d_loss:0.5061  g_loss:1.8176
# epoch:3902  d_loss:0.5075  g_loss:2.1570
# epoch:3903  d_loss:0.4661  g_loss:1.8460
# epoch:3904  d_loss:0.4867  g_loss:2.0972
# epoch:3905  d_loss:0.4724  g_loss:2.1634
# epoch:3906  d_loss:0.5877  g_loss:1.4886
# epoch:3907  d_loss:0.5549  g_loss:1.3720
# epoch:3908  d_loss:0.4541  g_loss:1.8015
# epoch:3909  d_loss:0.5745  g_loss:1.5511
# epoch:3910  d_loss:0.5699  g_loss:1.3017
# epoch:3911  d_loss:0.4659  g_loss:1.6388
# epoch:3912  d_loss:0.6392  g_loss:1.5795
# epoch:3913  d_loss:0.6545  g_loss:1.3825
# epoch:3914  d_loss:0.4428  g_loss:1.1866
# epoch:3915  d_loss:0.5485  g_loss:1.4393
# epoch:3916  d_loss:0.5173  g_loss:1.8866
# epoch:3917  d_loss:0.4435  g_loss:1.8914
# epoch:3918  d_loss:0.4534  g_loss:1.8973
# epoch:3919  d_loss:0.5764  g_loss:1.7147
# epoch:3920  d_loss:0.4681  g_loss:1.6940
# epoch:3921  d_loss:0.5804  g_loss:1.5165
# epoch:3922  d_loss:0.3720  g_loss:1.2956
# epoch:3923  d_loss:0.5041  g_loss:1.2765
# epoch:3924  d_loss:0.4263  g_loss:1.3405
# epoch:3925  d_loss:0.4398  g_loss:1.9169
# epoch:3926  d_loss:0.4798  g_loss:1.7906
# epoch:3927  d_loss:0.2970  g_loss:2.1389
# epoch:3928  d_loss:0.3703  g_loss:2.0249
# epoch:3929  d_loss:0.3696  g_loss:2.2315
# epoch:3930  d_loss:0.3873  g_loss:1.9530
# epoch:3931  d_loss:0.4670  g_loss:1.9575
# epoch:3932  d_loss:0.4007  g_loss:1.5958
# epoch:3933  d_loss:0.3411  g_loss:1.9480
# epoch:3934  d_loss:0.3025  g_loss:2.1919
# epoch:3935  d_loss:0.3843  g_loss:1.6460
# epoch:3936  d_loss:0.5084  g_loss:1.7915
# epoch:3937  d_loss:0.4459  g_loss:2.1025
# epoch:3938  d_loss:0.3977  g_loss:1.8324
# epoch:3939  d_loss:0.2609  g_loss:2.2160
# epoch:3940  d_loss:0.5446  g_loss:2.1392
# epoch:3941  d_loss:0.7013  g_loss:1.7899
# epoch:3942  d_loss:0.5164  g_loss:1.7125
# epoch:3943  d_loss:0.6624  g_loss:1.4308
# epoch:3944  d_loss:0.3796  g_loss:2.0259
# epoch:3945  d_loss:0.4104  g_loss:2.5332
# epoch:3946  d_loss:0.5945  g_loss:2.0319
# epoch:3947  d_loss:0.5865  g_loss:1.9367
# epoch:3948  d_loss:0.6353  g_loss:1.9192
# epoch:3949  d_loss:0.4611  g_loss:2.1274
# epoch:3950  d_loss:0.7312  g_loss:1.6611
# epoch:3951  d_loss:0.5541  g_loss:1.6226
# epoch:3952  d_loss:0.4676  g_loss:1.3526
# epoch:3953  d_loss:0.5498  g_loss:1.9386
# epoch:3954  d_loss:0.5557  g_loss:1.5630
# epoch:3955  d_loss:0.5016  g_loss:1.6023
# epoch:3956  d_loss:0.6095  g_loss:1.7552
# epoch:3957  d_loss:0.4387  g_loss:1.6156
# epoch:3958  d_loss:0.5529  g_loss:1.6234
# epoch:3959  d_loss:0.5125  g_loss:2.0577
# epoch:3960  d_loss:0.5295  g_loss:1.9709
# epoch:3961  d_loss:0.4167  g_loss:1.8621
# epoch:3962  d_loss:0.5446  g_loss:1.8795
# epoch:3963  d_loss:0.5155  g_loss:1.5150
# epoch:3964  d_loss:0.4576  g_loss:2.0559
# epoch:3965  d_loss:0.5863  g_loss:1.6828
# epoch:3966  d_loss:0.4072  g_loss:1.9433
# epoch:3967  d_loss:0.3825  g_loss:2.4336
# epoch:3968  d_loss:0.4255  g_loss:2.4378
# epoch:3969  d_loss:0.3975  g_loss:2.3315
# epoch:3970  d_loss:0.4775  g_loss:1.8214
# epoch:3971  d_loss:0.5642  g_loss:1.7951
# epoch:3972  d_loss:0.4545  g_loss:1.3335
# epoch:3973  d_loss:0.6157  g_loss:1.7783
# epoch:3974  d_loss:0.4827  g_loss:2.1277
# epoch:3975  d_loss:0.5086  g_loss:2.1568
# epoch:3976  d_loss:0.5502  g_loss:2.0152
# epoch:3977  d_loss:0.5716  g_loss:1.5930
# epoch:3978  d_loss:0.4630  g_loss:1.6208
# epoch:3979  d_loss:0.2933  g_loss:1.7861
# epoch:3980  d_loss:0.4836  g_loss:1.8254
# epoch:3981  d_loss:0.4747  g_loss:1.7622
# epoch:3982  d_loss:0.5172  g_loss:1.6706
# epoch:3983  d_loss:0.3462  g_loss:2.0651
# epoch:3984  d_loss:0.3645  g_loss:1.8665
# epoch:3985  d_loss:0.4319  g_loss:1.9878
# epoch:3986  d_loss:0.3380  g_loss:2.2597
# epoch:3987  d_loss:0.4559  g_loss:2.5443
# epoch:3988  d_loss:0.5872  g_loss:2.0792
# epoch:3989  d_loss:0.4402  g_loss:1.8191
# epoch:3990  d_loss:0.4685  g_loss:2.0467
# epoch:3991  d_loss:0.4399  g_loss:2.1548
# epoch:3992  d_loss:0.5147  g_loss:2.1745
# epoch:3993  d_loss:0.6141  g_loss:1.8162
# epoch:3994  d_loss:0.4946  g_loss:1.6509
# epoch:3995  d_loss:0.5041  g_loss:1.6285
# epoch:3996  d_loss:0.4532  g_loss:1.7919
# epoch:3997  d_loss:0.4232  g_loss:1.8001
# epoch:3998  d_loss:0.4245  g_loss:1.9180
# epoch:3999  d_loss:0.4349  g_loss:1.5791
# epoch:4000  d_loss:0.4637  g_loss:1.3884
# <ipython-input-8-94421baf8ad6>:30: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axs = plt.subplots(5, 5)
